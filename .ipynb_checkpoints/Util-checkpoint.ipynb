# %%
# setup library imports
import io, time, json
import requests
from bs4 import BeautifulSoup
from os import listdir
from os.path import isfile, join
from bs4 import BeautifulSoup

auth=('xiaoyuh1', 'jiandan123')


'''
用来下载老师的testcase
query: query file 的 url
param: param file 的url


使用范例
for i in range(63):
    query = 'http://boston.lti.cs.cmu.edu/classes/11-642/HW/HTS/tests/HW2-Train-%d.qry' % i
    param = 'http://boston.lti.cs.cmu.edu/classes/11-642/HW/HTS/tests/HW2-Train-%d.param' % i
    retrieve(query, param)

'''
def retrieve(query, param):
    query_response = requests.get(query, auth=auth)
    param_response = requests.get(param, auth=auth)
    
    p = param_response.content.strip()
    right = p[p.index('retrievalAlgorithm'):]
    algo = right[:right.index("\n")]
    print i, '-' * 10
    print algo
    print 
    print query_response.content.strip()
    
  
'''
用于网站左边的那个测试
pretty print返回的html页面
'''
def prettyPrintHTML(html):
    soup = BeautifulSoup(html)

    # kill all script and style elements
    for script in soup(["script", "style"]):
        script.extract()    # rip it out

    # get text
    text = soup.get_text(separator="\n")

    # break into lines and remove leading and trailing space on each
    lines = (line for line in text.splitlines())
    # break multi-headlines into a line each
    chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
    # drop blank lines
    text = '\n'.join(chunk for chunk in chunks if chunk)

    print(text)

    


'''
用于网站左边的那个测试
pretty print返回的html页面
提交试验结果，求MAP, P10, P10, P30

使用范例
autoSubmitCode('/Users/hexiaoyu/Desktop/11642 search/QueryEval/output/xxxx.teln')
'''    
def autoSubmitCode(filePath):
    testing_url = 'http://boston.lti.cs.cmu.edu/classes/11-642/HW/HTS/tes.cgi'
    payload = {'logtype': 'Summary', 'hwid': 'HW2', 'id':'xiaoyuh1'}
    files = {'infile': open(filePath, 'rb')}
    r = requests.post(testing_url, files=files, auth=auth, data=payload)
    html = r.content
    soup = BeautifulSoup(html)

    text_tmp = soup.get_text(separator="\n")
    text = [line.strip() for line in text_tmp.split('\n') if 'map ' in line or 'P10 ' in line or 'P20 ' in line or 'P30 ' in line]

    print '\n'.join(text)

    assert len(text) == 4
    temp = text.pop(0)
    text.append(temp)

    for line in text:
        print line[-6:]

    print ""
    
    
    
def getCheckListPlayload(nums):
    checklist = []
    for i in nums:
        checklist.append('HW2-Train-%d' % i)
    return checklist



'''
用于老师网站右侧，自动跑test case看程序是否正确
checklist2里面的内容是test case 的名字，最多10个
使用范例

checklist2 = ['HW2-train-Nested-0', 'HW2-train-Nested-1', 'HW2-train-Nested-2', 'HW2-train-Weight-0', 'HW2-train-Weight-1']
autoCheckCorrectness(checklist2)
'''
def autoCheckCorrectness(checklist):
    checking_url = 'http://boston.lti.cs.cmu.edu/classes/11-642/HW/HTS/hts.cgi'
    payload = {'submissionType': 'interim', 'hwid': 'HW2', 'test': checklist}
    filePath = r'/Users/hexiaoyu/Desktop/11642 search/QueryEval/QryEval.zip'
    files = {'infile': open(filePath, 'rb')}
    r = requests.post(checking_url, files=files, auth=auth, data=payload)
    html = r.content
    prettyPrintHTML(html)

# %%
mypath = '/Users/hexiaoyu/Desktop/11642 search/QueryEval/output/'
onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f)) and not f.startswith(".")]

for fileName in onlyfiles:
    if 'Exp5' in fileName:
        print fileName
        autoSubmitCode(join(mypath, fileName))

# %%
for i in range(63):
    query = 'http://boston.lti.cs.cmu.edu/classes/11-642/HW/HTS/tests/HW2-Train-%d.qry' % i
    param = 'http://boston.lti.cs.cmu.edu/classes/11-642/HW/HTS/tests/HW2-Train-%d.param' % i
    retrieve(query, param)

# %%
for i in range(0, 60, 10):
    checklist = getCheckListPlayload(range(i, i+10))
    autoCheckCorrectness(checklist)


checklist2 = ['HW2-train-Nested-0', 'HW2-train-Nested-1', 'HW2-train-Nested-2', 'HW2-train-Weight-0', 'HW2-train-Weight-1']
autoCheckCorrectness(checklist2)
# Out:
# Homework Testing Service
# Results for xiaoyuh1 on boston-web2.lti.cs.cmu.edu :
# ---- Your file is uploaded ----
# ---- Unpack the zip file ----Archive:
# /bos/www/htdocs/classes/11-642/HW/HTS/uploads-hts-interim/HW2-xiaoyuh1-Feb21-20:37:44/QryEval.zip
# creating: QryEval/
# inflating: QryEval/.DS_Store
# creating: __MACOSX/
# creating: __MACOSX/QryEval/
# inflating: __MACOSX/QryEval/._.DS_Store
# inflating: QryEval/DocLengthStore.java
# inflating: __MACOSX/QryEval/._DocLengthStore.java
# inflating: QryEval/DocLenStoreSimilarity.java
# inflating: __MACOSX/QryEval/._DocLenStoreSimilarity.java
# inflating: QryEval/EnglishAnalyzerConfigurable.java
# inflating: __MACOSX/QryEval/._EnglishAnalyzerConfigurable.java
# inflating: QryEval/Idx.java
# inflating: __MACOSX/QryEval/._Idx.java
# inflating: QryEval/InspectIndex.java
# inflating: __MACOSX/QryEval/._InspectIndex.java
# inflating: QryEval/InvList.java
# inflating: __MACOSX/QryEval/._InvList.java
# inflating: QryEval/Makefile
# inflating: __MACOSX/QryEval/._Makefile
# inflating: QryEval/PopData.java
# inflating: __MACOSX/QryEval/._PopData.java
# inflating: QryEval/Qry.java
# inflating: QryEval/QryEval.java
# inflating: QryEval/QryIop.java
# inflating: QryEval/QryIopNear.java
# inflating: QryEval/QryIopSyn.java
# inflating: __MACOSX/QryEval/._QryIopSyn.java
# inflating: QryEval/QryIopTerm.java
# inflating: QryEval/QryIopWindow.java
# inflating: QryEval/QryParser.java
# inflating: QryEval/QrySop.java
# inflating: QryEval/QrySopAnd.java
# inflating: QryEval/QrySopOr.java
# inflating: QryEval/QrySopScore.java
# inflating: QryEval/QrySopSum.java
# inflating: QryEval/QrySopWand.java
# inflating: QryEval/QrySopWsum.java
# inflating: QryEval/RetrievalModel.java
# inflating: QryEval/RetrievalModelBM25.java
# inflating: QryEval/RetrievalModelIndri.java
# inflating: QryEval/RetrievalModelRankedBoolean.java
# inflating: QryEval/RetrievalModelUnrankedBoolean.java
# inflating: __MACOSX/QryEval/._RetrievalModelUnrankedBoolean.java
# inflating: QryEval/ScoreList.java
# inflating: QryEval/TermVector.java
# inflating: __MACOSX/QryEval/._TermVector.java
# inflating: QryEval/Timer.java
# inflating: __MACOSX/QryEval/._Timer.java
# inflating: QryEval/xiaoyuh1-HW2-Report.pdf
# inflating: __MACOSX/QryEval/._xiaoyuh1-HW2-Report.pdf
# ---- Build the system ----javac 1.8.0_40# assume Linuxjavac -cp ".:lucene-4.3.0/*" -g *.java
# ---- Test your system ----
# java version "1.8.0_40"
# Java(TM) SE Runtime Environment (build 1.8.0_40-b25)
# Java HotSpot(TM) 64-Bit Server VM (build 25.40-b25, mixed mode)
# ---- Test HW2-Train-0----
# -- Parameter file: --indexPath=/bos/www/htdocs/classes/11-642/HW/HTS/inputs/indexqueryFilePath=/bos/www/htdocs/classes/11-642/HW/HTS/tests/HW2-Train-0.qrytrecEvalOutputPath=/bos/www/htdocs/classes/11-642/HW/HTS/uploads-hts-interim/HW2-xiaoyuh1-Feb21-20:37:44/outputs/HW2-Train-0.teInretrievalAlgorithm=IndriIndri:mu=2500Indri:lambda=0.4
# -- Your program stdout: --Memory used:
# 33 MBQuery 149:uplift at #AND(yellowstone.title national.body park.body)
# --> #and( #SCORE( uplift.body ) #AND( #SCORE( yellowstone.title ) #SCORE( national.body ) #SCORE( park.body ) ) )write149 to file149	Q0	clueweb09-en0003-01-26776	1	0.002382829323136939	run-1149	Q0	clueweb09-en0003-01-26777	2	0.002295078872663913	run-1149	Q0	clueweb09-en0004-31-10704	3	0.0021154638910798585	run-1149	Q0	clueweb09-en0003-01-26794	4	0.00187439667837724	run-1149	Q0	clueweb09-en0003-01-26774	5	0.0016692790127533386	run-1Time:
# 5373.221 ms
# -- trec_eval output: --num_q
# all	1num_ret
# all	100num_rel
# all	62num_rel_ret
# all	20map
# all	0.0686gm_ap
# all	0.0686R-prec
# all	0.3065bpref
# all	0.1400recip_rank
# all	0.1000ircl_prn.0.00
# all	0.3175ircl_prn.0.10
# all	0.3175ircl_prn.0.20
# all	0.3175ircl_prn.0.30
# all	0.3175ircl_prn.0.40
# all	0.0000ircl_prn.0.50
# all	0.0000ircl_prn.0.60
# all	0.0000ircl_prn.0.70
# all	0.0000ircl_prn.0.80
# all	0.0000ircl_prn.0.90
# all	0.0000ircl_prn.1.00
# all	0.0000P5
# all	0.0000P10
# all	0.1000P15
# all	0.1333P20
# all	0.1000P30
# all	0.0667P100
# all	0.2000P200
# all	0.1000P500
# all	0.0400P1000
# all	0.0200
# -- grade: --100%
# ---- Test HW2-Train-1----
# -- Parameter file: --indexPath=/bos/www/htdocs/classes/11-642/HW/HTS/inputs/indexqueryFilePath=/bos/www/htdocs/classes/11-642/HW/HTS/tests/HW2-Train-1.qrytrecEvalOutputPath=/bos/www/htdocs/classes/11-642/HW/HTS/uploads-hts-interim/HW2-xiaoyuh1-Feb21-20:37:44/outputs/HW2-Train-1.teInretrievalAlgorithm=BM25BM25:k_1=1.2BM25:b=0.75BM25:k_3=0.0
# -- Your program stdout: --Memory used:
# 33 MBQuery 190:brooks.title brothers.title clearance
# --> #sum( #SCORE( brook.title ) #SCORE( brother.title ) #SCORE( clearance.body ) )write190 to file190	Q0	clueweb09-en0000-18-21486	1	13.560241843548358	run-1190	Q0	clueweb09-en0006-16-02347	2	13.560241843548358	run-1190	Q0	clueweb09-en0006-16-02379	3	13.557525546170792	run-1190	Q0	clueweb09-en0006-16-02377	4	13.427060009940925	run-1190	Q0	clueweb09-en0006-16-02376	5	12.980955992342642	run-1Time:
# 1447.739 ms
# -- trec_eval output: --num_q
# all	1num_ret
# all	100num_rel
# all	20num_rel_ret
# all	6map
# all	0.0449gm_ap
# all	0.0449R-prec
# all	0.1500bpref
# all	0.0750recip_rank
# all	0.1429ircl_prn.0.00
# all	0.1765ircl_prn.0.10
# all	0.1765ircl_prn.0.20
# all	0.1724ircl_prn.0.30
# all	0.1053ircl_prn.0.40
# all	0.0000ircl_prn.0.50
# all	0.0000ircl_prn.0.60
# all	0.0000ircl_prn.0.70
# all	0.0000ircl_prn.0.80
# all	0.0000ircl_prn.0.90
# all	0.0000ircl_prn.1.00
# all	0.0000P5
# all	0.0000P10
# all	0.1000P15
# all	0.1333P20
# all	0.1500P30
# all	0.1667P100
# all	0.0600P200
# all	0.0300P500
# all	0.0120P1000
# all	0.0060
# -- grade: --100%
# ---- Test HW2-Train-2----
# -- Parameter file: --indexPath=/bos/www/htdocs/classes/11-642/HW/HTS/inputs/indexqueryFilePath=/bos/www/htdocs/classes/11-642/HW/HTS/tests/HW2-Train-2.qrytrecEvalOutputPath=/bos/www/htdocs/classes/11-642/HW/HTS/uploads-hts-interim/HW2-xiaoyuh1-Feb21-20:37:44/outputs/HW2-Train-2.teInretrievalAlgorithm=IndriIndri:mu=2500Indri:lambda=0.4
# -- Your program stdout: --Memory used:
# 33 MBQuery 190:#AND(brooks.title brothers.title) clearance
# --> #and( #AND( #SCORE( brook.title ) #SCORE( brother.title ) ) #SCORE( clearance.body ) )write190 to file190	Q0	clueweb09-en0004-65-06611	1	0.0035549388108642487	run-1190	Q0	clueweb09-en0006-48-13234	2	0.0010662999631638667	run-1190	Q0	clueweb09-en0011-98-26389	3	9.09465927475807E-4	run-1190	Q0	clueweb09-en0006-63-21300	4	9.040098975500937E-4	run-1190	Q0	clueweb09-en0007-24-07713	5	8.306585741410673E-4	run-1Time:
# 1240.767 ms
# -- trec_eval output: --num_q
# all	1num_ret
# all	100num_rel
# all	20num_rel_ret
# all	4map
# all	0.0167gm_ap
# all	0.0167R-prec
# all	0.0500bpref
# all	0.0900recip_rank
# all	0.1111ircl_prn.0.00
# all	0.1111ircl_prn.0.10
# all	0.0800ircl_prn.0.20
# all	0.0667ircl_prn.0.30
# all	0.0000ircl_prn.0.40
# all	0.0000ircl_prn.0.50
# all	0.0000ircl_prn.0.60
# all	0.0000ircl_prn.0.70
# all	0.0000ircl_prn.0.80
# all	0.0000ircl_prn.0.90
# all	0.0000ircl_prn.1.00
# all	0.0000P5
# all	0.0000P10
# all	0.1000P15
# all	0.0667P20
# all	0.0500P30
# all	0.0667P100
# all	0.0400P200
# all	0.0200P500
# all	0.0080P1000
# all	0.0040
# -- grade: --100%
# ---- Test HW2-Train-3----
# -- Parameter file: --indexPath=/bos/www/htdocs/classes/11-642/HW/HTS/inputs/indexqueryFilePath=/bos/www/htdocs/classes/11-642/HW/HTS/tests/HW2-Train-3.qrytrecEvalOutputPath=/bos/www/htdocs/classes/11-642/HW/HTS/uploads-hts-interim/HW2-xiaoyuh1-Feb21-20:37:44/outputs/HW2-Train-3.teInretrievalAlgorithm=BM25BM25:k_1=1.2BM25:b=0.75BM25:k_3=0.0
# -- Your program stdout: --Memory used:
# 33 MBQuery 190:#NEAR/2(brooks brothers) clearance
# --> #sum( #SCORE( #NEAR/2( brook.body brother.body ) ) #SCORE( clearance.body ) )write190 to file190	Q0	clueweb09-en0006-98-32888	1	11.46341765907876	run-1190	Q0	clueweb09-en0006-16-02379	2	11.190900553697354	run-1190	Q0	clueweb09-en0006-16-02376	3	11.037583907538567	run-1190	Q0	clueweb09-en0006-16-02366	4	10.99618037517167	run-1190	Q0	clueweb09-en0000-18-21486	5	10.961663597749347	run-1Time:
# 1284.618 ms
# -- trec_eval output: --num_q
# all	1num_ret
# all	100num_rel
# all	20num_rel_ret
# all	6map
# all	0.0496gm_ap
# all	0.0496R-prec
# all	0.2000bpref
# all	0.0825recip_rank
# all	0.0833ircl_prn.0.00
# all	0.2353ircl_prn.0.10
# all	0.2353ircl_prn.0.20
# all	0.2353ircl_prn.0.30
# all	0.1463ircl_prn.0.40
# all	0.0000ircl_prn.0.50
# all	0.0000ircl_prn.0.60
# all	0.0000ircl_prn.0.70
# all	0.0000ircl_prn.0.80
# all	0.0000ircl_prn.0.90
# all	0.0000ircl_prn.1.00
# all	0.0000P5
# all	0.0000P10
# all	0.0000P15
# all	0.2000P20
# all	0.2000P30
# all	0.1667P100
# all	0.0600P200
# all	0.0300P500
# all	0.0120P1000
# all	0.0060
# -- grade: --100%
# ---- Test HW2-Train-4----
# -- Parameter file: --indexPath=/bos/www/htdocs/classes/11-642/HW/HTS/inputs/indexqueryFilePath=/bos/www/htdocs/classes/11-642/HW/HTS/tests/HW2-Train-4.qrytrecEvalOutputPath=/bos/www/htdocs/classes/11-642/HW/HTS/uploads-hts-interim/HW2-xiaoyuh1-Feb21-20:37:44/outputs/HW2-Train-4.teInretrievalAlgorithm=IndriIndri:mu=2500Indri:lambda=0.4
# -- Your program stdout: --Memory used:
# 33 MBQuery 190:#NEAR/2(brooks brothers) clearance
# --> #and( #SCORE( #NEAR/2( brook.body brother.body ) ) #SCORE( clearance.body ) )write190 to file190	Q0	clueweb09-en0006-48-13234	1	0.0032540601702155053	run-1190	Q0	clueweb09-en0004-65-06611	2	0.002673406447179474	run-1190	Q0	clueweb09-en0006-98-32888	3	0.002080365209725724	run-1190	Q0	clueweb09-en0007-24-07713	4	0.001732587762562469	run-1190	Q0	clueweb09-en0009-98-27245	5	0.0017083392066322106	run-1Time:
# 1467.584 ms
# -- trec_eval output: --num_q
# all	1num_ret
# all	100num_rel
# all	20num_rel_ret
# all	6map
# all	0.0535gm_ap
# all	0.0535R-prec
# all	0.2000bpref
# all	0.1075recip_rank
# all	0.1250ircl_prn.0.00
# all	0.2308ircl_prn.0.10
# all	0.2308ircl_prn.0.20
# all	0.2222ircl_prn.0.30
# all	0.1538ircl_prn.0.40
# all	0.0000ircl_prn.0.50
# all	0.0000ircl_prn.0.60
# all	0.0000ircl_prn.0.70
# all	0.0000ircl_prn.0.80
# all	0.0000ircl_prn.0.90
# all	0.0000ircl_prn.1.00
# all	0.0000P5
# all	0.0000P10
# all	0.1000P15
# all	0.2000P20
# all	0.2000P30
# all	0.1667P100
# all	0.0600P200
# all	0.0300P500
# all	0.0120P1000
# all	0.0060
# -- grade: --100%
# ---- Test HW2-Train-5----
# -- Parameter file: --indexPath=/bos/www/htdocs/classes/11-642/HW/HTS/inputs/indexqueryFilePath=/bos/www/htdocs/classes/11-642/HW/HTS/tests/HW2-Train-5.qrytrecEvalOutputPath=/bos/www/htdocs/classes/11-642/HW/HTS/uploads-hts-interim/HW2-xiaoyuh1-Feb21-20:37:44/outputs/HW2-Train-5.teInretrievalAlgorithm=BM25BM25:k_1=1.2BM25:b=0.75BM25:k_3=0.0
# -- Your program stdout: --Memory used:
# 33 MBQuery 149:#SUM(uplift at #NEAR/5(yellowstone national park))
# --> #SUM( #SCORE( uplift.body ) #SCORE( #NEAR/5( yellowstone.body national.body park.body ) ) )write149 to file149	Q0	clueweb09-en0003-01-26776	1	10.936618352802041	run-1149	Q0	clueweb09-en0003-01-26777	2	10.876207622220287	run-1149	Q0	clueweb09-en0004-31-10704	3	10.607794267798315	run-1149	Q0	clueweb09-en0003-01-26774	4	10.249632649993462	run-1149	Q0	clueweb09-en0003-01-26781	5	10.249245206871027	run-1Time:
# 1433.688 ms
# -- trec_eval output: --num_q
# all	1num_ret
# all	100num_rel
# all	62num_rel_ret
# all	22map
# all	0.0987gm_ap
# all	0.0987R-prec
# all	0.3387bpref
# all	0.2081recip_rank
# all	0.0769ircl_prn.0.00
# all	0.3800ircl_prn.0.10
# all	0.3800ircl_prn.0.20
# all	0.3800ircl_prn.0.30
# all	0.3800ircl_prn.0.40
# all	0.0000ircl_prn.0.50
# all	0.0000ircl_prn.0.60
# all	0.0000ircl_prn.0.70
# all	0.0000ircl_prn.0.80
# all	0.0000ircl_prn.0.90
# all	0.0000ircl_prn.1.00
# all	0.0000P5
# all	0.0000P10
# all	0.0000P15
# all	0.1333P20
# all	0.2000P30
# all	0.2667P100
# all	0.2200P200
# all	0.1100P500
# all	0.0440P1000
# all	0.0220
# -- grade: --100%Your MAP differs from the expected MAP
# ---- Test HW2-Train-6----
# -- Parameter file: --indexPath=/bos/www/htdocs/classes/11-642/HW/HTS/inputs/indexqueryFilePath=/bos/www/htdocs/classes/11-642/HW/HTS/tests/HW2-Train-6.qrytrecEvalOutputPath=/bos/www/htdocs/classes/11-642/HW/HTS/uploads-hts-interim/HW2-xiaoyuh1-Feb21-20:37:44/outputs/HW2-Train-6.teInretrievalAlgorithm=IndriIndri:mu=2500Indri:lambda=0.4
# -- Your program stdout: --Memory used:
# 33 MBQuery 149:#AND(uplift at #NEAR/5(yellowstone national park))
# --> #AND( #SCORE( uplift.body ) #SCORE( #NEAR/5( yellowstone.body national.body park.body ) ) )write149 to file149	Q0	clueweb09-en0003-01-26777	1	0.0029082256872459797	run-1149	Q0	clueweb09-en0003-01-26776	2	0.0028461324800619376	run-1149	Q0	clueweb09-en0004-31-10704	3	0.002692747036142759	run-1149	Q0	clueweb09-en0003-01-26774	4	0.0020378122295627993	run-1149	Q0	clueweb09-en0003-01-26781	5	0.0020375438008495457	run-1Time:
# 1374.205 ms
# -- trec_eval output: --num_q
# all	1num_ret
# all	100num_rel
# all	62num_rel_ret
# all	27map
# all	0.1606gm_ap
# all	0.1606R-prec
# all	0.3226bpref
# all	0.2776recip_rank
# all	0.0909ircl_prn.0.00
# all	0.5357ircl_prn.0.10
# all	0.5357ircl_prn.0.20
# all	0.5357ircl_prn.0.30
# all	0.4130ircl_prn.0.40
# all	0.3125ircl_prn.0.50
# all	0.0000ircl_prn.0.60
# all	0.0000ircl_prn.0.70
# all	0.0000ircl_prn.0.80
# all	0.0000ircl_prn.0.90
# all	0.0000ircl_prn.1.00
# all	0.0000P5
# all	0.0000P10
# all	0.0000P15
# all	0.2667P20
# all	0.4000P30
# all	0.5000P100
# all	0.2700P200
# all	0.1350P500
# all	0.0540P1000
# all	0.0270
# -- grade: --100%Your MAP differs from the expected MAP
# ---- Test HW2-Train-7----
# -- Parameter file: --indexPath=/bos/www/htdocs/classes/11-642/HW/HTS/inputs/indexqueryFilePath=/bos/www/htdocs/classes/11-642/HW/HTS/tests/HW2-Train-7.qrytrecEvalOutputPath=/bos/www/htdocs/classes/11-642/HW/HTS/uploads-hts-interim/HW2-xiaoyuh1-Feb21-20:37:44/outputs/HW2-Train-7.teInretrievalAlgorithm=BM25BM25:k_1=1.2BM25:b=0.75BM25:k_3=0.0
# -- Your program stdout: --Memory used:
# 33 MBQuery 190:#SUM(#NEAR/2(brooks brothers) clearance brooks.url brothers.url)
# --> #SUM( #SCORE( #NEAR/2( brook.body brother.body ) ) #SCORE( clearance.body ) #SCORE( brook.url ) #SCORE( brother.url ) )write190 to file190	Q0	clueweb09-en0007-24-07713	1	17.559324291342673	run-1190	Q0	clueweb09-en0004-72-27126	2	17.268987232952323	run-1190	Q0	clueweb09-en0006-98-32888	3	17.215814900346984	run-1190	Q0	clueweb09-en0004-42-40299	4	17.017046907625804	run-1190	Q0	clueweb09-en0009-98-27245	5	17.010766136105314	run-1Time:
# 1296.253 ms
# -- trec_eval output: --num_q
# all	1num_ret
# all	100num_rel
# all	20num_rel_ret
# all	6map
# all	0.1075gm_ap
# all	0.1075R-prec
# all	0.2500bpref
# all	0.1975recip_rank
# all	0.5000ircl_prn.0.00
# all	0.5000ircl_prn.0.10
# all	0.5000ircl_prn.0.20
# all	0.5000ircl_prn.0.30
# all	0.0938ircl_prn.0.40
# all	0.0000ircl_prn.0.50
# all	0.0000ircl_prn.0.60
# all	0.0000ircl_prn.0.70
# all	0.0000ircl_prn.0.80
# all	0.0000ircl_prn.0.90
# all	0.0000ircl_prn.1.00
# all	0.0000P5
# all	0.2000P10
# all	0.4000P15
# all	0.2667P20
# all	0.2500P30
# all	0.1667P100
# all	0.0600P200
# all	0.0300P500
# all	0.0120P1000
# all	0.0060
# -- grade: --100%
# ---- Test HW2-Train-8----
# -- Parameter file: --indexPath=/bos/www/htdocs/classes/11-642/HW/HTS/inputs/indexqueryFilePath=/bos/www/htdocs/classes/11-642/HW/HTS/tests/HW2-Train-8.qrytrecEvalOutputPath=/bos/www/htdocs/classes/11-642/HW/HTS/uploads-hts-interim/HW2-xiaoyuh1-Feb21-20:37:44/outputs/HW2-Train-8.teInretrievalAlgorithm=IndriIndri:mu=2500Indri:lambda=0.4
# -- Your program stdout: --Memory used:
# 33 MBQuery 190:#AND(#AND(#NEAR/2(brooks brothers) clearance)
# #AND(brooks.url brothers.url))
# --> #AND( #AND( #SCORE( #NEAR/2( brook.body brother.body ) ) #SCORE( clearance.body ) ) #AND( #SCORE( brook.url ) #SCORE( brother.url ) ) )write190 to file190	Q0	clueweb09-en0006-98-32888	1	7.60229303185648E-4	run-1190	Q0	clueweb09-en0007-24-07713	2	6.944331494403374E-4	run-1190	Q0	clueweb09-en0009-98-27245	3	6.896862720575952E-4	run-1190	Q0	clueweb09-en0009-98-27243	4	6.392746680771944E-4	run-1190	Q0	clueweb09-en0006-48-12486	5	6.104167524216017E-4	run-1Time:
# 1540.405 ms
# -- trec_eval output: --num_q
# all	1num_ret
# all	100num_rel
# all	20num_rel_ret
# all	6map
# all	0.0893gm_ap
# all	0.0893R-prec
# all	0.2500bpref
# all	0.1875recip_rank
# all	0.2000ircl_prn.0.00
# all	0.4167ircl_prn.0.10
# all	0.4167ircl_prn.0.20
# all	0.4167ircl_prn.0.30
# all	0.0984ircl_prn.0.40
# all	0.0000ircl_prn.0.50
# all	0.0000ircl_prn.0.60
# all	0.0000ircl_prn.0.70
# all	0.0000ircl_prn.0.80
# all	0.0000ircl_prn.0.90
# all	0.0000ircl_prn.1.00
# all	0.0000P5
# all	0.2000P10
# all	0.3000P15
# all	0.3333P20
# all	0.2500P30
# all	0.1667P100
# all	0.0600P200
# all	0.0300P500
# all	0.0120P1000
# all	0.0060
# -- grade: --100%
# ---- Test HW2-Train-9----
# -- Parameter file: --indexPath=/bos/www/htdocs/classes/11-642/HW/HTS/inputs/indexqueryFilePath=/bos/www/htdocs/classes/11-642/HW/HTS/tests/HW2-Train-9.qrytrecEvalOutputPath=/bos/www/htdocs/classes/11-642/HW/HTS/uploads-hts-interim/HW2-xiaoyuh1-Feb21-20:37:44/outputs/HW2-Train-9.teInretrievalAlgorithm=BM25BM25:k_1=1.2BM25:b=0.75BM25:k_3=0.0
# -- Your program stdout: --Memory used:
# 33 MBQuery 190:brooks brothers clearance
# --> #sum( #SCORE( brook.body ) #SCORE( brother.body ) #SCORE( clearance.body ) )write190 to file190	Q0	clueweb09-en0006-98-32888	1	10.835506976981724	run-1190	Q0	clueweb09-en0006-16-02379	2	10.736374406339944	run-1190	Q0	clueweb09-en0006-16-02376	3	10.68390285239424	run-1190	Q0	clueweb09-en0000-18-21486	4	10.596611994255166	run-1190	Q0	clueweb09-en0006-16-02347	5	10.596611994255166	run-1Time:
# 2380.334 ms
# -- trec_eval output: --num_q
# all	1num_ret
# all	100num_rel
# all	20num_rel_ret
# all	6map
# all	0.0470gm_ap
# all	0.0470R-prec
# all	0.2000bpref
# all	0.0750recip_rank
# all	0.0769ircl_prn.0.00
# all	0.2353ircl_prn.0.10
# all	0.2353ircl_prn.0.20
# all	0.2353ircl_prn.0.30
# all	0.1364ircl_prn.0.40
# all	0.0000ircl_prn.0.50
# all	0.0000ircl_prn.0.60
# all	0.0000ircl_prn.0.70
# all	0.0000ircl_prn.0.80
# all	0.0000ircl_prn.0.90
# all	0.0000ircl_prn.1.00
# all	0.0000P5
# all	0.0000P10
# all	0.0000P15
# all	0.1333P20
# all	0.2000P30
# all	0.1333P100
# all	0.0600P200
# all	0.0300P500
# all	0.0120P1000
# all	0.0060
# -- grade: --100%
# ---- End of your system's output ----
# ---- Done ----
# Homework Testing Service
# Results for xiaoyuh1 on boston-web1.lti.cs.cmu.edu :
# ---- Your file is uploaded ----
# ---- Unpack the zip file ----Archive:
# /bos/www/htdocs/classes/11-642/HW/HTS/uploads-hts-interim/HW2-xiaoyuh1-Feb21-20:38:43/QryEval.zip
# creating: QryEval/
# inflating: QryEval/.DS_Store
# creating: __MACOSX/
# creating: __MACOSX/QryEval/
# inflating: __MACOSX/QryEval/._.DS_Store
# inflating: QryEval/DocLengthStore.java
# inflating: __MACOSX/QryEval/._DocLengthStore.java
# inflating: QryEval/DocLenStoreSimilarity.java
# inflating: __MACOSX/QryEval/._DocLenStoreSimilarity.java
# inflating: QryEval/EnglishAnalyzerConfigurable.java
# inflating: __MACOSX/QryEval/._EnglishAnalyzerConfigurable.java
# inflating: QryEval/Idx.java
# inflating: __MACOSX/QryEval/._Idx.java
# inflating: QryEval/InspectIndex.java
# inflating: __MACOSX/QryEval/._InspectIndex.java
# inflating: QryEval/InvList.java
# inflating: __MACOSX/QryEval/._InvList.java
# inflating: QryEval/Makefile
# inflating: __MACOSX/QryEval/._Makefile
# inflating: QryEval/PopData.java
# inflating: __MACOSX/QryEval/._PopData.java
# inflating: QryEval/Qry.java
# inflating: QryEval/QryEval.java
# inflating: QryEval/QryIop.java
# inflating: QryEval/QryIopNear.java
# inflating: QryEval/QryIopSyn.java
# inflating: __MACOSX/QryEval/._QryIopSyn.java
# inflating: QryEval/QryIopTerm.java
# inflating: QryEval/QryIopWindow.java
# inflating: QryEval/QryParser.java
# inflating: QryEval/QrySop.java
# inflating: QryEval/QrySopAnd.java
# inflating: QryEval/QrySopOr.java
# inflating: QryEval/QrySopScore.java
# inflating: QryEval/QrySopSum.java
# inflating: QryEval/QrySopWand.java
# inflating: QryEval/QrySopWsum.java
# inflating: QryEval/RetrievalModel.java
# inflating: QryEval/RetrievalModelBM25.java
# inflating: QryEval/RetrievalModelIndri.java
# inflating: QryEval/RetrievalModelRankedBoolean.java
# inflating: QryEval/RetrievalModelUnrankedBoolean.java
# inflating: __MACOSX/QryEval/._RetrievalModelUnrankedBoolean.java
# inflating: QryEval/ScoreList.java
# inflating: QryEval/TermVector.java
# inflating: __MACOSX/QryEval/._TermVector.java
# inflating: QryEval/Timer.java
# inflating: __MACOSX/QryEval/._Timer.java
# inflating: QryEval/xiaoyuh1-HW2-Report.pdf
# inflating: __MACOSX/QryEval/._xiaoyuh1-HW2-Report.pdf
# ---- Build the system ----javac 1.8.0_40# assume Linuxjavac -cp ".:lucene-4.3.0/*" -g *.java
# ---- Test your system ----
# java version "1.8.0_40"
# Java(TM) SE Runtime Environment (build 1.8.0_40-b25)
# Java HotSpot(TM) 64-Bit Server VM (build 25.40-b25, mixed mode)
# ---- Test HW2-Train-10----
# -- Parameter file: --indexPath=/bos/www/htdocs/classes/11-642/HW/HTS/inputs/indexqueryFilePath=/bos/www/htdocs/classes/11-642/HW/HTS/tests/HW2-Train-10.qrytrecEvalOutputPath=/bos/www/htdocs/classes/11-642/HW/HTS/uploads-hts-interim/HW2-xiaoyuh1-Feb21-20:38:43/outputs/HW2-Train-10.teInretrievalAlgorithm=BM25BM25:k_1=1.2BM25:b=0.75BM25:k_3=0.0
# -- Your program stdout: --Memory used:
# 33 MBQuery 149:#SUM(uplift at yellowstone national park)
# --> #SUM( #SCORE( uplift.body ) #SCORE( yellowstone.body ) #SCORE( national.body ) #SCORE( park.body ) )write149 to file149	Q0	clueweb09-en0003-01-26776	1	14.574382797870442	run-1149	Q0	clueweb09-en0003-01-26777	2	14.411237658534066	run-1149	Q0	clueweb09-en0004-31-10704	3	14.153955985556788	run-1149	Q0	clueweb09-en0003-01-26774	4	13.828709608136016	run-1149	Q0	clueweb09-en0003-01-26781	5	13.828387045804705	run-1Time:
# 5807.300 ms
# -- trec_eval output: --num_q
# all	1num_ret
# all	100num_rel
# all	62num_rel_ret
# all	26map
# all	0.1219gm_ap
# all	0.1219R-prec
# all	0.3548bpref
# all	0.2183recip_rank
# all	0.0714ircl_prn.0.00
# all	0.3793ircl_prn.0.10
# all	0.3793ircl_prn.0.20
# all	0.3793ircl_prn.0.30
# all	0.3793ircl_prn.0.40
# all	0.3333ircl_prn.0.50
# all	0.0000ircl_prn.0.60
# all	0.0000ircl_prn.0.70
# all	0.0000ircl_prn.0.80
# all	0.0000ircl_prn.0.90
# all	0.0000ircl_prn.1.00
# all	0.0000P5
# all	0.0000P10
# all	0.0000P15
# all	0.0667P20
# all	0.2000P30
# all	0.3333P100
# all	0.2600P200
# all	0.1300P500
# all	0.0520P1000
# all	0.0260
# -- grade: --100%
# ---- Test HW2-Train-11----
# -- Parameter file: --indexPath=/bos/www/htdocs/classes/11-642/HW/HTS/inputs/indexqueryFilePath=/bos/www/htdocs/classes/11-642/HW/HTS/tests/HW2-Train-11.qrytrecEvalOutputPath=/bos/www/htdocs/classes/11-642/HW/HTS/uploads-hts-interim/HW2-xiaoyuh1-Feb21-20:38:43/outputs/HW2-Train-11.teInretrievalAlgorithm=IndriIndri:mu=2500Indri:lambda=0.4
# -- Your program stdout: --Memory used:
# 33 MBQuery 190:brooks brothers clearance
# --> #and( #SCORE( brook.body ) #SCORE( brother.body ) #SCORE( clearance.body ) )write190 to file190	Q0	clueweb09-en0009-98-27245	1	0.0035475565219150367	run-1190	Q0	clueweb09-en0000-35-19942	2	0.003054745362551013	run-1190	Q0	clueweb09-en0003-67-02800	3	0.0030287720799559094	run-1190	Q0	clueweb09-en0009-98-27243	4	0.00292888391528342	run-1190	Q0	clueweb09-en0006-98-32888	5	0.00250594058070247	run-1Time:
# 2329.679 ms
# -- trec_eval output: --num_q
# all	1num_ret
# all	100num_rel
# all	20num_rel_ret
# all	6map
# all	0.0437gm_ap
# all	0.0437R-prec
# all	0.1500bpref
# all	0.0975recip_rank
# all	0.1429ircl_prn.0.00
# all	0.1765ircl_prn.0.10
# all	0.1765ircl_prn.0.20
# all	0.1429ircl_prn.0.30
# all	0.1429ircl_prn.0.40
# all	0.0000ircl_prn.0.50
# all	0.0000ircl_prn.0.60
# all	0.0000ircl_prn.0.70
# all	0.0000ircl_prn.0.80
# all	0.0000ircl_prn.0.90
# all	0.0000ircl_prn.1.00
# all	0.0000P5
# all	0.0000P10
# all	0.1000P15
# all	0.1333P20
# all	0.1500P30
# all	0.1000P100
# all	0.0600P200
# all	0.0300P500
# all	0.0120P1000
# all	0.0060
# -- grade: --100%
# ---- Test HW2-Train-12----
# -- Parameter file: --indexPath=/bos/www/htdocs/classes/11-642/HW/HTS/inputs/indexqueryFilePath=/bos/www/htdocs/classes/11-642/HW/HTS/tests/HW2-Train-12.qrytrecEvalOutputPath=/bos/www/htdocs/classes/11-642/HW/HTS/uploads-hts-interim/HW2-xiaoyuh1-Feb21-20:38:43/outputs/HW2-Train-12.teInretrievalAlgorithm=BM25BM25:k_1=1.2BM25:b=0.75BM25:k_3=0.0
# -- Your program stdout: --Memory used:
# 33 MBQuery 149:uplift at yellowstone national park
# --> #sum( #SCORE( uplift.body ) #SCORE( yellowstone.body ) #SCORE( national.body ) #SCORE( park.body ) )write149 to file149	Q0	clueweb09-en0003-01-26776	1	14.574382797870442	run-1149	Q0	clueweb09-en0003-01-26777	2	14.411237658534066	run-1149	Q0	clueweb09-en0004-31-10704	3	14.153955985556788	run-1149	Q0	clueweb09-en0003-01-26774	4	13.828709608136016	run-1149	Q0	clueweb09-en0003-01-26781	5	13.828387045804705	run-1Time:
# 6635.989 ms
# -- trec_eval output: --num_q
# all	1num_ret
# all	100num_rel
# all	62num_rel_ret
# all	26map
# all	0.1219gm_ap
# all	0.1219R-prec
# all	0.3548bpref
# all	0.2183recip_rank
# all	0.0714ircl_prn.0.00
# all	0.3793ircl_prn.0.10
# all	0.3793ircl_prn.0.20
# all	0.3793ircl_prn.0.30
# all	0.3793ircl_prn.0.40
# all	0.3333ircl_prn.0.50
# all	0.0000ircl_prn.0.60
# all	0.0000ircl_prn.0.70
# all	0.0000ircl_prn.0.80
# all	0.0000ircl_prn.0.90
# all	0.0000ircl_prn.1.00
# all	0.0000P5
# all	0.0000P10
# all	0.0000P15
# all	0.0667P20
# all	0.2000P30
# all	0.3333P100
# all	0.2600P200
# all	0.1300P500
# all	0.0520P1000
# all	0.0260
# -- grade: --100%
# ---- Test HW2-Train-13----
# -- Parameter file: --indexPath=/bos/www/htdocs/classes/11-642/HW/HTS/inputs/indexqueryFilePath=/bos/www/htdocs/classes/11-642/HW/HTS/tests/HW2-Train-13.qrytrecEvalOutputPath=/bos/www/htdocs/classes/11-642/HW/HTS/uploads-hts-interim/HW2-xiaoyuh1-Feb21-20:38:43/outputs/HW2-Train-13.teInretrievalAlgorithm=IndriIndri:mu=2500Indri:lambda=0.4
# -- Your program stdout: --Memory used:
# 33 MBQuery 149:uplift at yellowstone national park
# --> #and( #SCORE( uplift.body ) #SCORE( yellowstone.body ) #SCORE( national.body ) #SCORE( park.body ) )write149 to file149	Q0	clueweb09-en0003-01-26777	1	0.005598361083710795	run-1149	Q0	clueweb09-en0004-31-10704	2	0.00553143069778117	run-1149	Q0	clueweb09-en0003-01-26776	3	0.0053050360299650885	run-1149	Q0	clueweb09-en0003-01-26774	4	0.004559610152457776	run-1149	Q0	clueweb09-en0003-01-26781	5	0.004559026489599923	run-1Time:
# 5385.138 ms
# -- trec_eval output: --num_q
# all	1num_ret
# all	100num_rel
# all	62num_rel_ret
# all	22map
# all	0.1234gm_ap
# all	0.1234R-prec
# all	0.2742bpref
# all	0.2216recip_rank
# all	0.1250ircl_prn.0.00
# all	0.5625ircl_prn.0.10
# all	0.5625ircl_prn.0.20
# all	0.3400ircl_prn.0.30
# all	0.2292ircl_prn.0.40
# all	0.0000ircl_prn.0.50
# all	0.0000ircl_prn.0.60
# all	0.0000ircl_prn.0.70
# all	0.0000ircl_prn.0.80
# all	0.0000ircl_prn.0.90
# all	0.0000ircl_prn.1.00
# all	0.0000P5
# all	0.0000P10
# all	0.3000P15
# all	0.5333P20
# all	0.5000P30
# all	0.4000P100
# all	0.2200P200
# all	0.1100P500
# all	0.0440P1000
# all	0.0220
# -- grade: --100%
# ---- Test HW2-Train-14----
# Elapsed:
# 10 seconds
# -- Parameter file: --indexPath=/bos/www/htdocs/classes/11-642/HW/HTS/inputs/indexqueryFilePath=/bos/www/htdocs/classes/11-642/HW/HTS/tests/HW2-Train-14.qrytrecEvalOutputPath=/bos/www/htdocs/classes/11-642/HW/HTS/uploads-hts-interim/HW2-xiaoyuh1-Feb21-20:38:43/outputs/HW2-Train-14.teInretrievalAlgorithm=IndriIndri:mu=2500Indri:lambda=0.4
# -- Your program stdout: --Memory used:
# 33 MBQuery 149:#AND(uplift at yellowstone national park)
# --> #AND( #SCORE( uplift.body ) #SCORE( yellowstone.body ) #SCORE( national.body ) #SCORE( park.body ) )write149 to file149	Q0	clueweb09-en0003-01-26777	1	0.005598361083710795	run-1149	Q0	clueweb09-en0004-31-10704	2	0.00553143069778117	run-1149	Q0	clueweb09-en0003-01-26776	3	0.0053050360299650885	run-1149	Q0	clueweb09-en0003-01-26774	4	0.004559610152457776	run-1149	Q0	clueweb09-en0003-01-26781	5	0.004559026489599923	run-1Time:
# 10516.314 ms
# -- trec_eval output: --num_q
# all	1num_ret
# all	100num_rel
# all	62num_rel_ret
# all	22map
# all	0.1234gm_ap
# all	0.1234R-prec
# all	0.2742bpref
# all	0.2216recip_rank
# all	0.1250ircl_prn.0.00
# all	0.5625ircl_prn.0.10
# all	0.5625ircl_prn.0.20
# all	0.3400ircl_prn.0.30
# all	0.2292ircl_prn.0.40
# all	0.0000ircl_prn.0.50
# all	0.0000ircl_prn.0.60
# all	0.0000ircl_prn.0.70
# all	0.0000ircl_prn.0.80
# all	0.0000ircl_prn.0.90
# all	0.0000ircl_prn.1.00
# all	0.0000P5
# all	0.0000P10
# all	0.3000P15
# all	0.5333P20
# all	0.5000P30
# all	0.4000P100
# all	0.2200P200
# all	0.1100P500
# all	0.0440P1000
# all	0.0220
# -- grade: --100%
# ---- Test HW2-Train-15----
# -- Parameter file: --indexPath=/bos/www/htdocs/classes/11-642/HW/HTS/inputs/indexqueryFilePath=/bos/www/htdocs/classes/11-642/HW/HTS/tests/HW2-Train-15.qrytrecEvalOutputPath=/bos/www/htdocs/classes/11-642/HW/HTS/uploads-hts-interim/HW2-xiaoyuh1-Feb21-20:38:43/outputs/HW2-Train-15.teInretrievalAlgorithm=BM25BM25:k_1=1.2BM25:b=0.75BM25:k_3=0.0
# -- Your program stdout: --Memory used:
# 33 MBQuery 190:#SUM(brooks brothers clearance)
# --> #SUM( #SCORE( brook.body ) #SCORE( brother.body ) #SCORE( clearance.body ) )write190 to file190	Q0	clueweb09-en0006-98-32888	1	10.835506976981724	run-1190	Q0	clueweb09-en0006-16-02379	2	10.736374406339944	run-1190	Q0	clueweb09-en0006-16-02376	3	10.68390285239424	run-1190	Q0	clueweb09-en0000-18-21486	4	10.596611994255166	run-1190	Q0	clueweb09-en0006-16-02347	5	10.596611994255166	run-1Time:
# 2473.863 ms
# -- trec_eval output: --num_q
# all	1num_ret
# all	100num_rel
# all	20num_rel_ret
# all	6map
# all	0.0470gm_ap
# all	0.0470R-prec
# all	0.2000bpref
# all	0.0750recip_rank
# all	0.0769ircl_prn.0.00
# all	0.2353ircl_prn.0.10
# all	0.2353ircl_prn.0.20
# all	0.2353ircl_prn.0.30
# all	0.1364ircl_prn.0.40
# all	0.0000ircl_prn.0.50
# all	0.0000ircl_prn.0.60
# all	0.0000ircl_prn.0.70
# all	0.0000ircl_prn.0.80
# all	0.0000ircl_prn.0.90
# all	0.0000ircl_prn.1.00
# all	0.0000P5
# all	0.0000P10
# all	0.0000P15
# all	0.1333P20
# all	0.2000P30
# all	0.1333P100
# all	0.0600P200
# all	0.0300P500
# all	0.0120P1000
# all	0.0060
# -- grade: --100%
# ---- Test HW2-Train-16----
# -- Parameter file: --indexPath=/bos/www/htdocs/classes/11-642/HW/HTS/inputs/indexqueryFilePath=/bos/www/htdocs/classes/11-642/HW/HTS/tests/HW2-Train-16.qrytrecEvalOutputPath=/bos/www/htdocs/classes/11-642/HW/HTS/uploads-hts-interim/HW2-xiaoyuh1-Feb21-20:38:43/outputs/HW2-Train-16.teInretrievalAlgorithm=IndriIndri:mu=2500Indri:lambda=0.4
# -- Your program stdout: --Memory used:
# 33 MBQuery 190:#AND(brooks brothers clearance)
# --> #AND( #SCORE( brook.body ) #SCORE( brother.body ) #SCORE( clearance.body ) )write190 to file190	Q0	clueweb09-en0009-98-27245	1	0.0035475565219150367	run-1190	Q0	clueweb09-en0000-35-19942	2	0.003054745362551013	run-1190	Q0	clueweb09-en0003-67-02800	3	0.0030287720799559094	run-1190	Q0	clueweb09-en0009-98-27243	4	0.00292888391528342	run-1190	Q0	clueweb09-en0006-98-32888	5	0.00250594058070247	run-1Time:
# 2515.160 ms
# -- trec_eval output: --num_q
# all	1num_ret
# all	100num_rel
# all	20num_rel_ret
# all	6map
# all	0.0437gm_ap
# all	0.0437R-prec
# all	0.1500bpref
# all	0.0975recip_rank
# all	0.1429ircl_prn.0.00
# all	0.1765ircl_prn.0.10
# all	0.1765ircl_prn.0.20
# all	0.1429ircl_prn.0.30
# all	0.1429ircl_prn.0.40
# all	0.0000ircl_prn.0.50
# all	0.0000ircl_prn.0.60
# all	0.0000ircl_prn.0.70
# all	0.0000ircl_prn.0.80
# all	0.0000ircl_prn.0.90
# all	0.0000ircl_prn.1.00
# all	0.0000P5
# all	0.0000P10
# all	0.1000P15
# all	0.1333P20
# all	0.1500P30
# all	0.1000P100
# all	0.0600P200
# all	0.0300P500
# all	0.0120P1000
# all	0.0060
# -- grade: --100%
# ---- Test HW2-Train-17----
# -- Parameter file: --indexPath=/bos/www/htdocs/classes/11-642/HW/HTS/inputs/indexqueryFilePath=/bos/www/htdocs/classes/11-642/HW/HTS/tests/HW2-Train-17.qrytrecEvalOutputPath=/bos/www/htdocs/classes/11-642/HW/HTS/uploads-hts-interim/HW2-xiaoyuh1-Feb21-20:38:43/outputs/HW2-Train-17.teInretrievalAlgorithm=BM25BM25:k_1=1.2BM25:b=0.75BM25:k_3=0.0
# -- Your program stdout: --Memory used:
# 33 MBQuery 52:avp.inlink avp.title avp.keywords avp.body
# --> #sum( #SCORE( avp.inlink ) #SCORE( avp.title ) #SCORE( avp.keywords ) #SCORE( avp.body ) )write52 to file52	Q0	clueweb09-en0007-56-15204	1	27.539833935609693	run-152	Q0	clueweb09-en0010-35-03150	2	26.697197963186966	run-152	Q0	clueweb09-en0010-35-03191	3	26.40850753773124	run-152	Q0	clueweb09-en0007-37-33556	4	25.783334795717366	run-152	Q0	clueweb09-en0011-39-28881	5	25.7529275262407	run-1Time:
# 1001.764 ms
# -- trec_eval output: --num_q
# all	1num_ret
# all	100num_rel
# all	47num_rel_ret
# all	16map
# all	0.0497gm_ap
# all	0.0497R-prec
# all	0.1064bpref
# all	0.0498recip_rank
# all	0.1429ircl_prn.0.00
# all	0.2000ircl_prn.0.10
# all	0.1829ircl_prn.0.20
# all	0.1829ircl_prn.0.30
# all	0.1829ircl_prn.0.40
# all	0.0000ircl_prn.0.50
# all	0.0000ircl_prn.0.60
# all	0.0000ircl_prn.0.70
# all	0.0000ircl_prn.0.80
# all	0.0000ircl_prn.0.90
# all	0.0000ircl_prn.1.00
# all	0.0000P5
# all	0.0000P10
# all	0.2000P15
# all	0.1333P20
# all	0.1000P30
# all	0.0667P100
# all	0.1600P200
# all	0.0800P500
# all	0.0320P1000
# all	0.0160
# -- grade: --100%
# ---- Test HW2-Train-18----
# -- Parameter file: --indexPath=/bos/www/htdocs/classes/11-642/HW/HTS/inputs/indexqueryFilePath=/bos/www/htdocs/classes/11-642/HW/HTS/tests/HW2-Train-18.qrytrecEvalOutputPath=/bos/www/htdocs/classes/11-642/HW/HTS/uploads-hts-interim/HW2-xiaoyuh1-Feb21-20:38:43/outputs/HW2-Train-18.teInretrievalAlgorithm=IndriIndri:mu=2500Indri:lambda=0.4
# -- Your program stdout: --Memory used:
# 33 MBQuery 52:avp.inlink avp.title avp.keywords avp.body
# --> #and( #SCORE( avp.inlink ) #SCORE( avp.title ) #SCORE( avp.keywords ) #SCORE( avp.body ) )write52 to file52	Q0	clueweb09-en0000-77-18405	1	0.0021115820146806125	run-152	Q0	clueweb09-en0010-35-03145	2	0.0020198387382467714	run-152	Q0	clueweb09-en0010-35-03150	3	0.0019347656131004324	run-152	Q0	clueweb09-en0010-35-03191	4	0.0019185299904013486	run-152	Q0	clueweb09-en0010-35-03189	5	0.00147797913403708	run-1Time:
# 1183.458 ms
# -- trec_eval output: --num_q
# all	1num_ret
# all	100num_rel
# all	47num_rel_ret
# all	14map
# all	0.0430gm_ap
# all	0.0430R-prec
# all	0.0851bpref
# all	0.0602recip_rank
# all	0.1111ircl_prn.0.00
# all	0.1875ircl_prn.0.10
# all	0.1667ircl_prn.0.20
# all	0.1667ircl_prn.0.30
# all	0.0000ircl_prn.0.40
# all	0.0000ircl_prn.0.50
# all	0.0000ircl_prn.0.60
# all	0.0000ircl_prn.0.70
# all	0.0000ircl_prn.0.80
# all	0.0000ircl_prn.0.90
# all	0.0000ircl_prn.1.00
# all	0.0000P5
# all	0.0000P10
# all	0.1000P15
# all	0.1333P20
# all	0.1500P30
# all	0.1333P100
# all	0.1400P200
# all	0.0700P500
# all	0.0280P1000
# all	0.0140
# -- grade: --100%
# ---- Test HW2-Train-19----
# -- Parameter file: --indexPath=/bos/www/htdocs/classes/11-642/HW/HTS/inputs/indexqueryFilePath=/bos/www/htdocs/classes/11-642/HW/HTS/tests/HW2-Train-19.qrytrecEvalOutputPath=/bos/www/htdocs/classes/11-642/HW/HTS/uploads-hts-interim/HW2-xiaoyuh1-Feb21-20:38:43/outputs/HW2-Train-19.teInretrievalAlgorithm=BM25BM25:k_1=1.2BM25:b=0.75BM25:k_3=0.0
# -- Your program stdout: --Memory used:
# 33 MBQuery 71:living in india.title
# --> #sum( #SCORE( living.body ) #SCORE( india.title ) )write71 to file71	Q0	clueweb09-en0007-10-10672	1	5.977220499196152	run-171	Q0	clueweb09-en0007-18-18457	2	5.968241216671121	run-171	Q0	clueweb09-en0004-30-21214	3	5.744506762358892	run-171	Q0	clueweb09-en0006-01-08786	4	5.702405349977742	run-171	Q0	clueweb09-en0003-31-16394	5	5.485205374277457	run-1Time:
# 3173.911 ms
# -- trec_eval output: --num_q
# all	1num_ret
# all	100num_rel
# all	91num_rel_ret
# all	14map
# all	0.0344gm_ap
# all	0.0344R-prec
# all	0.1538bpref
# all	0.1235recip_rank
# all	0.2500ircl_prn.0.00
# all	0.2857ircl_prn.0.10
# all	0.2264ircl_prn.0.20
# all	0.0000ircl_prn.0.30
# all	0.0000ircl_prn.0.40
# all	0.0000ircl_prn.0.50
# all	0.0000ircl_prn.0.60
# all	0.0000ircl_prn.0.70
# all	0.0000ircl_prn.0.80
# all	0.0000ircl_prn.0.90
# all	0.0000ircl_prn.1.00
# all	0.0000P5
# all	0.2000P10
# all	0.2000P15
# all	0.2667P20
# all	0.2000P30
# all	0.2333P100
# all	0.1400P200
# all	0.0700P500
# all	0.0280P1000
# all	0.0140
# -- grade: --100%
# ---- End of your system's output ----
# ---- Done ----
