# %%
# setup library imports
import io, time, json
import requests
from bs4 import BeautifulSoup
auth=('xiaoyuh1', 'jiandan123')


'''
用来下载老师的testcase
query: query file 的 url
param: param file 的url


使用范例
for i in range(63):
    query = 'http://boston.lti.cs.cmu.edu/classes/11-642/HW/HTS/tests/HW2-Train-%d.qry' % i
    param = 'http://boston.lti.cs.cmu.edu/classes/11-642/HW/HTS/tests/HW2-Train-%d.param' % i
    retrieve(query, param)

'''
def retrieve(query, param):
    query_response = requests.get(query, auth=auth)
    param_response = requests.get(param, auth=auth)
    
    p = param_response.content.strip()
    right = p[p.index('retrievalAlgorithm'):]
    algo = right[:right.index("\n")]
    print i, '-' * 10
    print algo
    print 
    print query_response.content.strip()

# %%
from bs4 import BeautifulSoup


'''
用于网站左边的那个测试
pretty print返回的html页面
'''
def prettyPrintHTML(html):
    soup = BeautifulSoup(html)

    # kill all script and style elements
    for script in soup(["script", "style"]):
        script.extract()    # rip it out

    # get text
    text = soup.get_text()

    # break into lines and remove leading and trailing space on each
    lines = (line for line in text.splitlines())
    # break multi-headlines into a line each
    chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
    # drop blank lines
    text = '\n'.join(chunk for chunk in chunks if chunk)

    print(text)
    
    

'''
用于网站左边的那个测试
pretty print返回的html页面
提交试验结果，求MAP, P10, P10, P30

使用范例
autoSubmitCode('/Users/hexiaoyu/Desktop/11642 search/QueryEval/output/xxxx.teln')
'''    
def autoSubmitCode(filePath):
    from os import listdir
    from os.path import isfile, join
    testing_url = 'http://boston.lti.cs.cmu.edu/classes/11-642/HW/HTS/tes.cgi'
    payload = {'logtype': 'Summary', 'hwid': 'HW2', 'id':'xiaoyuh1'}
    files = {'infile': open(filePath, 'rb')}
    r = requests.post(testing_url, files=files, auth=auth, data=payload)
    html = r.content
    soup = BeautifulSoup(html)

    text_tmp = soup.get_text(separator="\n")
    text = [line.strip() for line in text_tmp.split('\n') if 'map ' in line or 'P10 ' in line or 'P20 ' in line or 'P30 ' in line]

    print '\n'.join(text)

    assert len(text) == 4
    temp = text.pop(0)
    text.append(temp)

    for line in text:
        print line[-6:]

    print ""
    


mypath = '/Users/hexiaoyu/Desktop/11642 search/QueryEval/output/'
onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f)) and not f.startswith(".")]

for fileName in onlyfiles:
    if 'Exp5' in fileName:
        print fileName
        autoSubmitCode(join(mypath, fileName))
# Out:
# HW2-Exp5-1-Indri-2500-0.40.teln
# map            	all	0.0295
# P10            	all	0.2000
# P20            	all	0.1500
# P30            	all	0.1000
# 0.2000
# 0.1500
# 0.1000
# 0.0295
#
# HW2-Exp5-2-Indri-2500-0.40.teln
# map            	all	0.0284
# P10            	all	0.2000
# P20            	all	0.1500
# P30            	all	0.1000
# 0.2000
# 0.1500
# 0.1000
# 0.0284
#
# HW2-Exp5-3-Indri-2500-0.40.teln
# map            	all	0.0263
# P10            	all	0.2000
# P20            	all	0.1500
# P30            	all	0.1000
# 0.2000
# 0.1500
# 0.1000
# 0.0263
#
# HW2-Exp5-4-Indri-2500-0.40.teln
# map            	all	0.0284
# P10            	all	0.2000
# P20            	all	0.1500
# P30            	all	0.1000
# 0.2000
# 0.1500
# 0.1000
# 0.0284
#
# HW2-Exp5-5-Indri-2500-0.40.teln
# map            	all	0.0293
# P10            	all	0.2000
# P20            	all	0.1500
# P30            	all	0.1000
# 0.2000
# 0.1500
# 0.1000
# 0.0293

# %%
def getCheckListPlayload(nums):
    checklist = []
    for i in nums:
        checklist.append('HW2-Train-%d' % i)
    return checklist


def autoCheckCorrectness(checklist):
    checking_url = 'http://boston.lti.cs.cmu.edu/classes/11-642/HW/HTS/hts.cgi'
    payload = {'submissionType': 'interim', 'hwid': 'HW2', 'test': checklist}
    filePath = r'/Users/hexiaoyu/Desktop/11642 search/QueryEval/QryEval.zip'
    files = {'infile': open(filePath, 'rb')}
    r = requests.post(checking_url, files=files, auth=auth, data=payload)
    html = r.content
    prettyPrintHTML(html)


# for i in range(0, 60, 10):
#     checklist = getCheckListPlayload(range(i, i+10))
#     autoCheckCorrectness(checklist)


# checklist2 = ['HW2-train-Nested-0', 'HW2-train-Nested-1', 'HW2-train-Nested-2', 'HW2-train-Weight-0', 'HW2-train-Weight-1']
# autoCheckCorrectness(checklist2)

# %%
for i in range(63):
    query = 'http://boston.lti.cs.cmu.edu/classes/11-642/HW/HTS/tests/HW2-Train-%d.qry' % i
    param = 'http://boston.lti.cs.cmu.edu/classes/11-642/HW/HTS/tests/HW2-Train-%d.param' % i
    retrieve(query, param)
# Out:
# 0 ----------
# retrievalAlgorithm=Indri
#
# 149:uplift at #AND(yellowstone.title national.body park.body)
# 1 ----------
# retrievalAlgorithm=BM25
#
# 190:brooks.title brothers.title clearance
# 2 ----------
# retrievalAlgorithm=Indri
#
# 190:#AND(brooks.title brothers.title) clearance
# 3 ----------
# retrievalAlgorithm=BM25
#
# 190:#NEAR/2(brooks brothers) clearance
# 4 ----------
# retrievalAlgorithm=Indri
#
# 190:#NEAR/2(brooks brothers) clearance
# 5 ----------
# retrievalAlgorithm=BM25
#
# 149:#SUM(uplift at #NEAR/5(yellowstone national park))
# 6 ----------
# retrievalAlgorithm=Indri
#
# 149:#AND(uplift at #NEAR/5(yellowstone national park))
# 7 ----------
# retrievalAlgorithm=BM25
#
# 190:#SUM(#NEAR/2(brooks brothers) clearance brooks.url brothers.url)
# 8 ----------
# retrievalAlgorithm=Indri
#
# 190:#AND(#AND(#NEAR/2(brooks brothers) clearance)   #AND(brooks.url brothers.url))
# 9 ----------
# retrievalAlgorithm=BM25
#
# 190:brooks brothers clearance
# 10 ----------
# retrievalAlgorithm=BM25
#
# 149:#SUM(uplift at yellowstone national park)
# 11 ----------
# retrievalAlgorithm=Indri
#
# 190:brooks brothers clearance
# 12 ----------
# retrievalAlgorithm=BM25
#
# 149:uplift at yellowstone national park
# 13 ----------
# retrievalAlgorithm=Indri
#
# 149:uplift at yellowstone national park
# 14 ----------
# retrievalAlgorithm=Indri
#
# 149:#AND(uplift at yellowstone national park)
# 15 ----------
# retrievalAlgorithm=BM25
#
# 190:#SUM(brooks brothers clearance)
# 16 ----------
# retrievalAlgorithm=Indri
#
# 190:#AND(brooks brothers clearance)
# 17 ----------
# retrievalAlgorithm=BM25
#
# 52:avp.inlink avp.title avp.keywords avp.body
# 18 ----------
# retrievalAlgorithm=Indri
#
# 52:avp.inlink avp.title avp.keywords avp.body
# 19 ----------
# retrievalAlgorithm=BM25
#
# 71:living in india.title
# 20 ----------
# retrievalAlgorithm=Indri
#
# 71:living in india.title
# 21 ----------
# retrievalAlgorithm=BM25
#
# 149:#SUM(uplift at yellowstone.title national.body park.body)
# 22 ----------
# retrievalAlgorithm=Indri
#
# 10:#AND(cheap internet)
# 12:#AND(djs)
# 26:#AND(lower heart rate)
# 29:#AND(ps 2 games)
# 33:#AND(elliptical trainer)
# 52:#AND(avp)
# 71:#AND(living in india)
# 102:#AND(fickle creek farm)
# 149:#AND(uplift at yellowstone national park)
# 190:#AND(brooks brothers clearance)
# 23 ----------
# retrievalAlgorithm=Indri
#
# 71:living in india.title
# 24 ----------
# retrievalAlgorithm=BM25
#
# 71:living in india.title
# 25 ----------
# retrievalAlgorithm=Indri
#
# 149:#AND(#AND(uplift at yellowstone.title national.body park.body) yellowstone.keywords)
# 26 ----------
# retrievalAlgorithm=BM25
#
# 149:#SUM(#SUM(uplift at yellowstone.title national.body park.body) yellowstone.keywords)
# 27 ----------
# retrievalAlgorithm=Indri
#
# 190:#AND(brooks.title brothers.title) clearance
# 28 ----------
# retrievalAlgorithm=BM25
#
# 190:#SUM(brooks.title brothers.title) clearance
# 29 ----------
# retrievalAlgorithm=Indri
#
# 190:#NEAR/2(brooks brothers) clearance
# 30 ----------
# retrievalAlgorithm=BM25
#
# 190:#NEAR/2(brooks brothers) clearance
# 31 ----------
# retrievalAlgorithm=Indri
#
# 149:#AND(uplift at #NEAR/5(yellowstone national park))
# 32 ----------
# retrievalAlgorithm=BM25
#
# 149:#SUM(uplift at #NEAR/5(yellowstone national park))
# 33 ----------
# retrievalAlgorithm=BM25
#
# 10:#SUM(cheap internet)
# 12:#SUM(djs)
# 26:#SUM(lower heart rate)
# 29:#SUM(ps 2 games)
# 33:#SUM(elliptical trainer)
# 52:#SUM(avp)
# 71:#SUM(living in india)
# 102:#SUM(fickle creek farm)
# 149:#SUM(uplift at yellowstone national park)
# 190:#SUM(brooks brothers clearance)
# 34 ----------
# retrievalAlgorithm=Indri
#
# 190:#AND(#AND(#NEAR/2(brooks brothers) clearance)   #AND(brooks.url brothers.url))
# 35 ----------
# retrievalAlgorithm=BM25
#
# 190:#SUM(#SUM(#NEAR/2(brooks brothers) clearance)   #SUM(brooks.url brothers.url))
# 36 ----------
# retrievalAlgorithm=Indri
#
# 149:#AND(#AND(uplift at #NEAR/5(yellowstone national park))  #AND(uplift at #NEAR/10(yellowstone #NEAR/2(national park))))
# 37 ----------
# retrievalAlgorithm=BM25
#
# 149:#SUM(#SUM(uplift at #NEAR/5(yellowstone national park))  #SUM(uplift at #NEAR/10(yellowstone #NEAR/2(national park))))
# 38 ----------
# retrievalAlgorithm=Indri
#
# 29:#AND(#AND(#NEAR/2(ps.title 2.title) games)   #AND(#NEAR/2(ps.body 2.body) games.body))
# 39 ----------
# retrievalAlgorithm=BM25
#
# 29:#SUM(#SUM(#NEAR/2(ps.title 2.title) games)   #SUM(#NEAR/2(ps.body 2.body) games.body))
# 40 ----------
# retrievalAlgorithm=Indri
#
# 190:#AND(brooks brothers #SYN(clearance sale discount))
# 41 ----------
# retrievalAlgorithm=BM25
#
# 10:#WINDOW/8(cheap internet)
# 42 ----------
# retrievalAlgorithm=BM25
#
# 26:lower #WINDOW/8(heart rate)
# 43 ----------
# retrievalAlgorithm=BM25
#
# 29:#WINDOW/8(ps 2) games
# 44 ----------
# retrievalAlgorithm=BM25
#
# 33:#WINDOW/8(elliptical trainer)
# 45 ----------
# retrievalAlgorithm=BM25
#
# 190:#WINDOW/8(brooks brothers) clearance
# 46 ----------
# retrievalAlgorithm=Indri
#
# 10:#WAND( 0.3 cheap 0.7 internet )
# 47 ----------
# retrievalAlgorithm=Indri
#
# 26:#WAND( 0.5 lower 0.3 heart 0.2 rate )
# 48 ----------
# retrievalAlgorithm=Indri
#
# 29:#WAND( 0.5 ps 0.3 2 0.2 games )
# 49 ----------
# retrievalAlgorithm=Indri
#
# 33:#WAND( 0.6 elliptical 0.4 trainer )
# 50 ----------
# retrievalAlgorithm=Indri
#
# 71:#WAND( 0.3 living 0.1 in 0.6 india )
# 51 ----------
# retrievalAlgorithm=Indri
#
# 10:#WINDOW/8(cheap internet)
# 52 ----------
# retrievalAlgorithm=Indri
#
# 26:lower #WINDOW/8(heart rate)
# 53 ----------
# retrievalAlgorithm=Indri
#
# 29:#WINDOW/8(ps 2) games
# 54 ----------
# retrievalAlgorithm=Indri
#
# 33:#WINDOW/8(elliptical trainer)
# 55 ----------
# retrievalAlgorithm=Indri
#
# 190:#WINDOW/8(brooks brothers) clearance
# 56 ----------
# retrievalAlgorithm=Indri
#
# 12:#WSUM (0.5 djs.title 0.5 #AND(disk.body jockey.body) )
# 57 ----------
# retrievalAlgorithm=Indri
#
# 52:#WSUM(0.3 avp 0.7 #AND(Association of volleyball) )
# 58 ----------
# retrievalAlgorithm=Indri
#
# 102:#WSUM(0.3 #AND(fickle.title creek.title farm.title) 0.7 #AND(fickle creek farm) )
# 59 ----------
# retrievalAlgorithm=Indri
#
# 149:#WSUM(0.3 #AND(yellowstone.title national.title park.title) 0.7 #AND(uplift at yellowstone national park))
# 60 ----------
# retrievalAlgorithm=Indri
#
# 190:#WSUM(0.3 #AND(brooks.title brothers.title) 0.7 #AND(brooks brothers clearance))
# 61 ----------
# retrievalAlgorithm=Indri
#
# 26:#WINDOW/50(lower heart rate)
# 149:#WINDOW/150(uplift at #NEAR/5(yellowstone national park))
# 190:#WINDOW/100(brooks brothers clearance)
# 62 ----------
# retrievalAlgorithm=BM25
#
# 26:#WINDOW/50(lower heart rate)
# 149:#WINDOW/150(uplift at #NEAR/5(yellowstone national park))
# 190:#WINDOW/100(brooks brothers clearance)
