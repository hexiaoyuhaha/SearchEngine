# %%
# setup library imports
import io, time, json
import requests
from bs4 import BeautifulSoup
from os import listdir
from os.path import isfile, join
from bs4 import BeautifulSoup

# 请填写你作业网站的登录名和密码
auth=('xiaoyuh1', 'jiandan123')


'''
用来下载老师的testcase
query: query file 的 url
param: param file 的url


使用范例
for i in range(63):
    query = 'http://boston.lti.cs.cmu.edu/classes/11-642/HW/HTS/tests/HW2-Train-%d.qry' % i
    param = 'http://boston.lti.cs.cmu.edu/classes/11-642/HW/HTS/tests/HW2-Train-%d.param' % i
    retrieve(query, param)

'''
def retrieve(query, param):
    query_response = requests.get(query, auth=auth)
    param_response = requests.get(param, auth=auth)
    
    p = param_response.content.strip()
    right = p[p.index('retrievalAlgorithm'):]
    algo = right[:right.index("\n")]
    print i, '-' * 10
    print algo
    print 
    print query_response.content.strip()
    
  
'''
用于网站左边的那个测试
pretty print返回的html页面
'''
def prettyPrintHTML(html):
    soup = BeautifulSoup(html)

    # kill all script and style elements
    for script in soup(["script", "style"]):
        script.extract()    # rip it out

    # get text
    text = soup.get_text(separator="\n")

    # break into lines and remove leading and trailing space on each
    lines = (line for line in text.splitlines())
    # break multi-headlines into a line each
    chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
    # drop blank lines
    text = '\n'.join(chunk for chunk in chunks if chunk)

    print(text)

    

def getLeftSideSoup(filePath, logtype):
    testing_url = 'http://boston.lti.cs.cmu.edu/classes/11-642/HW/HTS/tes.cgi'
    payload = {'logtype': logtype, 'hwid': 'HW3', 'id':'xiaoyuh1'}
    files = {'infile': open(filePath, 'rb')}
    r = requests.post(testing_url, files=files, auth=auth, data=payload)
    html = r.content
    return BeautifulSoup(html)
    

'''
用于网站左边的那个测试
pretty print返回的html页面
提交试验结果，求MAP, P10, P10, P30

使用范例
autoSubmitCode('/Users/hexiaoyu/Desktop/11642 search/QueryEval/output/xxxx.teln')
'''    
def getTrecSummaryScore(filePath):
    soup = getLeftSideSoup(filePath, 'Summary')

    text_tmp = soup.get_text(separator="\n")
    text = [line.strip() for line in text_tmp.split('\n') if 'map ' in line or 'P10 ' in line or 'P20 ' in line or 'P30 ' in line]
#     print '\n'.join(text)
    assert len(text) == 4
    temp = text.pop(0)
    text.append(temp)

    for line in text:
        print line[-6:]
    print ""
    

'''
Retrieve the detailed score from trec_eval service
If the total query number is N, there will be 
N line "map 195 0.0148"
1 line "map all 0.2063"
discard the map all line
'''
def getTrecDetailedScore(filePath):
    soup = getLeftSideSoup(filePath, 'Detailed')
    text_tmp = soup.get_text(separator="\n")
    text = [line.strip() for line in text_tmp.split('\n') if 'map ' in line and 'all' not in line]
    mapScore = [line[-6:] for line in text]
#     print "text"
#     print text
#     print " | ".join(mapScore)
#     print len(mapScore)
    return mapScore
    

    
'''
这个是HW3中用来得到win loss rate的工具。

# 先得到baseline的TrecDetailedScore
baseLine = getTrecDetailedScore("hw3/output/E1-RankedBoolean.teln")
# 然后比较baseLine和my-otuput.teln的win loss 
getWinLoss(baseLine, 'My-output.teln')
# sample output: win, loss, equal 10 10  0
'''
def getWinLoss(baseLine, filePath):
    myScore = getTrecDetailedScore(filePath)
    for base, my in zip(baseLine, myScore):
        print base, my
    win = sum([1 for base, my in zip(baseLine, myScore) if base < my])
    loss = sum([1 for base, my in zip(baseLine, myScore) if base > my])
    equal = sum([1 for base, my in zip(baseLine, myScore) if base == my])
#     print " ".join(baseLine)
#     print " ".join(myScore)
    print "win, loss, equal %2d %2d %2d" % (win, loss, equal)
    
    
    
'''
autoCheckCorrectness的helper函数
'''
def getCheckListPlayload(nums):
    checklist = []
    for i in nums:
        checklist.append('HW3-Train-%d' % i)
    return checklist


'''
用于老师网站右侧，自动跑test case看程序是否正确
checklist2里面的内容是test case 的名字，最多10个
使用范例

checklist2 = ['HW2-train-Nested-0', 'HW2-train-Nested-1', 'HW2-train-Nested-2', 'HW2-train-Weight-0', 'HW2-train-Weight-1']
autoCheckCorrectness(checklist2)
'''
def autoCheckCorrectness(checklist):
    checking_url = 'http://boston.lti.cs.cmu.edu/classes/11-642/HW/HTS/hts.cgi'
    payload = {'submissionType': 'interim', 'hwid': 'HW3', 'test': checklist}
    filePath = r'/Users/hexiaoyu/Desktop/11642 search/QueryEval/QryEval.zip'
    files = {'infile': open(filePath, 'rb')}
    r = requests.post(checking_url, files=files, auth=auth, data=payload)
    html = r.content
    prettyPrintHTML(html)

# %%
mypath = '/Users/hexiaoyu/Desktop/11642 search/QueryEval/hw4/output'
onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f)) and not f.startswith(".")]

for fileName in onlyfiles:
    if 'comb' in fileName and 'teIn' in fileName:
        print fileName
        getTrecSummaryScore(join(mypath, fileName))
# Out:
# comb1.teIn
# 0.2840
# 0.2260
# 0.2107
# 0.1114
#
# comb2.teIn
# 0.2840
# 0.2280
# 0.2093
# 0.1121
#
# comb3.teIn
# 0.2840
# 0.2300
# 0.2147
# 0.1211

# %%
checklist = getCheckListPlayload(range(0, 10))
autoCheckCorrectness(checklist)
# Out:
# Homework Testing Service
# Results for xiaoyuh1 on boston-web2.lti.cs.cmu.edu :
# ---- Your file is uploaded ----
# ---- Unpack the zip file ----
# Archive:
# /bos/www/htdocs/classes/11-642/HW/HTS/uploads-hts-interim/HW3-xiaoyuh1-Mar21-22:51:50/QryEval.zip
# creating: QryEval/
# inflating: QryEval/.DS_Store
# creating: __MACOSX/
# creating: __MACOSX/QryEval/
# inflating: __MACOSX/QryEval/._.DS_Store
# inflating: QryEval/DocLengthStore.java
# inflating: __MACOSX/QryEval/._DocLengthStore.java
# inflating: QryEval/DocLenStoreSimilarity.java
# inflating: __MACOSX/QryEval/._DocLenStoreSimilarity.java
# inflating: QryEval/EnglishAnalyzerConfigurable.java
# inflating: __MACOSX/QryEval/._EnglishAnalyzerConfigurable.java
# inflating: QryEval/Entry.java
# inflating: QryEval/Idx.java
# inflating: __MACOSX/QryEval/._Idx.java
# inflating: QryEval/InspectIndex.java
# inflating: __MACOSX/QryEval/._InspectIndex.java
# inflating: QryEval/InvList.java
# inflating: __MACOSX/QryEval/._InvList.java
# inflating: QryEval/Makefile
# inflating: __MACOSX/QryEval/._Makefile
# inflating: QryEval/PopData.java
# inflating: __MACOSX/QryEval/._PopData.java
# inflating: QryEval/Qry.java
# inflating: QryEval/QryEval.java
# inflating: QryEval/QryEvalQueryExpension.java
# inflating: QryEval/QryIop.java
# inflating: QryEval/QryIopNear.java
# inflating: QryEval/QryIopSyn.java
# inflating: __MACOSX/QryEval/._QryIopSyn.java
# inflating: QryEval/QryIopTerm.java
# inflating: QryEval/QryIopWindow.java
# inflating: QryEval/QryParser.java
# inflating: QryEval/QrySop.java
# inflating: QryEval/QrySopAnd.java
# inflating: QryEval/QrySopOr.java
# inflating: QryEval/QrySopScore.java
# inflating: QryEval/QrySopSum.java
# inflating: QryEval/QrySopWand.java
# inflating: QryEval/QrySopWsum.java
# inflating: QryEval/RetrievalModel.java
# inflating: QryEval/RetrievalModelBM25.java
# inflating: QryEval/RetrievalModelIndri.java
# inflating: QryEval/RetrievalModelRankedBoolean.java
# inflating: QryEval/RetrievalModelUnrankedBoolean.java
# inflating: __MACOSX/QryEval/._RetrievalModelUnrankedBoolean.java
# inflating: QryEval/ScoreList.java
# inflating: QryEval/TermScoreList.java
# inflating: QryEval/TermVector.java
# inflating: QryEval/Timer.java
# inflating: __MACOSX/QryEval/._Timer.java
# inflating: QryEval/xiaoyuh1-HW3-Report.docx
# inflating: __MACOSX/QryEval/._xiaoyuh1-HW3-Report.docx
# inflating: QryEval/xiaoyuh1-HW3-Report.pdf
# inflating: __MACOSX/QryEval/._xiaoyuh1-HW3-Report.pdf
# inflating: QryEval/~$aoyuh1-HW3-Report.docx
# inflating: __MACOSX/QryEval/._~$aoyuh1-HW3-Report.docx
# ---- Build the system ----
# javac 1.8.0_40
# # assume Linux
# javac -cp ".:lucene-4.3.0/*" -g *.java
# ---- Test your system ----
# java version "1.8.0_40"
# Java(TM) SE Runtime Environment (build 1.8.0_40-b25)
# Java HotSpot(TM) 64-Bit Server VM (build 25.40-b25, mixed mode)
# ---- Test HW3-Train-0----
# -- Parameter file: --
# cat: /bos/www/htdocs/classes/11-642/HW/HTS/tests/HW3-Train-0.param: No such file or directory
# -- Your program stdout: --
# Exception in thread "main" java.util.NoSuchElementException: No line found
# at java.util.Scanner.nextLine(Scanner.java:1540)
# at QryEval.readParameterFile(QryEval.java:365)
# at QryEval.main(QryEval.java:38)
# make: *** [teIn] Error 1
# ---- Test HW3-Train-1----
# Elapsed:
# 10 seconds
# Elapsed:
# 20 seconds
# Elapsed:
# 30 seconds
# Elapsed:
# 40 seconds
# Elapsed:
# 50 seconds
# Elapsed:
# 60 seconds
# Elapsed:
# 70 seconds
# Elapsed:
# 80 seconds
# Elapsed:
# 90 seconds
# Elapsed:
# 100 seconds
# Elapsed:
# 110 seconds
# Elapsed:
# 120 seconds
# Elapsed:
# 130 seconds
# -- Parameter file: --
# indexPath=/bos/www/htdocs/classes/11-642/HW/HTS/inputs/index
# queryFilePath=/bos/www/htdocs/classes/11-642/HW/HTS/tests/HW3-Train-1.qry
# trecEvalOutputPath=/bos/www/htdocs/classes/11-642/HW/HTS/uploads-hts-interim/HW3-xiaoyuh1-Mar21-22:51:50/outputs/HW3-Train-1.teIn
# retrievalAlgorithm=Indri
# Indri:mu=1000
# Indri:lambda=0.7
# fb=true
# fbDocs=10
# fbTerms=10
# fbMu=0
# fbOrigWeight=0.5
# fbExpansionQueryFile=/bos/www/htdocs/classes/11-642/HW/HTS/uploads-hts-interim/HW3-xiaoyuh1-Mar21-22:51:50/outputs/HW3-Train-1.qryOut
# -- Your program stdout: --
# Memory used:
# 33 MB
# Query 10:cheap internet
# -- Expand Query
# --> #and( #SCORE( cheap.body ) #SCORE( internet.body ) )
# qexpanded:#wand (0.0136 package 0.0146 provider 0.0149 service 0.0152 fast 0.0171 dial 0.0298 domain 0.0541 web 0.0817 host 0.0902 internet 0.1535 cheap )
# qcombined:#wand( 0.500000 #and(cheap internet)
# 0.500000 #wand (0.0136 package 0.0146 provider 0.0149 service 0.0152 fast 0.0171 dial 0.0298 domain 0.0541 web 0.0817 host 0.0902 internet 0.1535 cheap ) )
# --> #wand( #and( #SCORE( cheap.body ) #SCORE( internet.body ) ) #wand( #SCORE( package.body ) #SCORE( provider.body ) #SCORE( service.body ) #SCORE( fast.body ) #SCORE( dial.body ) #SCORE( domain.body ) #SCORE( web.body ) #SCORE( host.body ) #SCORE( internet.body ) #SCORE( cheap.body ) ) )
# write10 to file
# 10	Q0	clueweb09-en0001-18-32681	1	0.013614325086211649	run-1
# 10	Q0	clueweb09-en0003-07-27266	2	0.01277741541127722	run-1
# 10	Q0	clueweb09-en0000-95-28647	3	0.010643971721975275	run-1
# 10	Q0	clueweb09-en0000-95-28646	4	0.010629856623199405	run-1
# 10	Q0	clueweb09-en0000-95-28660	5	0.010629856623199405	run-1
# Time:
# 132460.199 ms
# -- trec_eval output: --
# num_q
# all	1
# num_ret
# all	100
# num_rel
# all	100
# num_rel_ret
# all	29
# map
# all	0.0692
# gm_ap
# all	0.0692
# R-prec
# all	0.2900
# bpref
# all	0.1829
# recip_rank
# all	0.0769
# ircl_prn.0.00
# all	0.3111
# ircl_prn.0.10
# all	0.3111
# ircl_prn.0.20
# all	0.3111
# ircl_prn.0.30
# all	0.0000
# ircl_prn.0.40
# all	0.0000
# ircl_prn.0.50
# all	0.0000
# ircl_prn.0.60
# all	0.0000
# ircl_prn.0.70
# all	0.0000
# ircl_prn.0.80
# all	0.0000
# ircl_prn.0.90
# all	0.0000
# ircl_prn.1.00
# all	0.0000
# P5
# all	0.0000
# P10
# all	0.0000
# P15
# all	0.0667
# P20
# all	0.0500
# P30
# all	0.1667
# P100
# all	0.2900
# P200
# all	0.1450
# P500
# all	0.0580
# P1000
# all	0.0290
# -- grade: --
# 100%
# ---- Test HW3-Train-2----
# Elapsed:
# 10 seconds
# Elapsed:
# 20 seconds
# Elapsed:
# 30 seconds
# -- Parameter file: --
# indexPath=/bos/www/htdocs/classes/11-642/HW/HTS/inputs/index
# queryFilePath=/bos/www/htdocs/classes/11-642/HW/HTS/tests/HW3-Train-2.qry
# trecEvalOutputPath=/bos/www/htdocs/classes/11-642/HW/HTS/uploads-hts-interim/HW3-xiaoyuh1-Mar21-22:51:50/outputs/HW3-Train-2.teIn
# retrievalAlgorithm=Indri
# Indri:mu=1000
# Indri:lambda=0.7
# fb=true
# fbDocs=10
# fbTerms=10
# fbMu=0
# fbOrigWeight=0.5
# fbExpansionQueryFile=/bos/www/htdocs/classes/11-642/HW/HTS/uploads-hts-interim/HW3-xiaoyuh1-Mar21-22:51:50/outputs/HW3-Train-2.qryOut
# -- Your program stdout: --
# Memory used:
# 33 MB
# Query 12:djs
# -- Expand Query
# --> #SCORE( djs.body )
# qexpanded:#wand (0.0218 oh 0.0253 ny 0.0278 ca 0.0286 pa 0.0309 dj 0.0499 band 0.0532 disc 0.0605 jockey 0.0680 entertainer 1.2850 djs )
# qcombined:#wand( 0.500000 #and(djs)
# 0.500000 #wand (0.0218 oh 0.0253 ny 0.0278 ca 0.0286 pa 0.0309 dj 0.0499 band 0.0532 disc 0.0605 jockey 0.0680 entertainer 1.2850 djs ) )
# --> #wand( #SCORE( djs.body ) #wand( #SCORE( oh.body ) #SCORE( ny.body ) #SCORE( ca.body ) #SCORE( pa.body ) #SCORE( dj.body ) #SCORE( band.body ) #SCORE( disc.body ) #SCORE( jockey.body ) #SCORE( entertainer.body ) #SCORE( djs.body ) ) )
# write12 to file
# 12	Q0	clueweb09-en0007-24-16724	1	0.03178886009319872	run-1
# 12	Q0	clueweb09-en0007-24-16722	2	0.03122214930481142	run-1
# 12	Q0	clueweb09-en0007-24-16726	3	0.028631708463121897	run-1
# 12	Q0	clueweb09-en0007-24-16725	4	0.024553376172915087	run-1
# 12	Q0	clueweb09-en0004-09-06992	5	0.02382870820818835	run-1
# Time:
# 31063.613 ms
# -- trec_eval output: --
# num_q
# all	1
# num_ret
# all	100
# num_rel
# all	162
# num_rel_ret
# all	59
# map
# all	0.2795
# gm_ap
# all	0.2795
# R-prec
# all	0.3642
# bpref
# all	0.3512
# recip_rank
# all	1.0000
# ircl_prn.0.00
# all	1.0000
# ircl_prn.0.10
# all	0.8462
# ircl_prn.0.20
# all	0.7021
# ircl_prn.0.30
# all	0.6282
# ircl_prn.0.40
# all	0.0000
# ircl_prn.0.50
# all	0.0000
# ircl_prn.0.60
# all	0.0000
# ircl_prn.0.70
# all	0.0000
# ircl_prn.0.80
# all	0.0000
# ircl_prn.0.90
# all	0.0000
# ircl_prn.1.00
# all	0.0000
# P5
# all	1.0000
# P10
# all	0.9000
# P15
# all	0.8667
# P20
# all	0.8000
# P30
# all	0.8333
# P100
# all	0.5900
# P200
# all	0.2950
# P500
# all	0.1180
# P1000
# all	0.0590
# -- grade: --
# 100%
# ---- Test HW3-Train-3----
# Elapsed:
# 10 seconds
# Elapsed:
# 20 seconds
# Elapsed:
# 30 seconds
# Elapsed:
# 40 seconds
# Elapsed:
# 50 seconds
# Elapsed:
# 60 seconds
# Elapsed:
# 70 seconds
# -- Parameter file: --
# indexPath=/bos/www/htdocs/classes/11-642/HW/HTS/inputs/index
# queryFilePath=/bos/www/htdocs/classes/11-642/HW/HTS/tests/HW3-Train-3.qry
# trecEvalOutputPath=/bos/www/htdocs/classes/11-642/HW/HTS/uploads-hts-interim/HW3-xiaoyuh1-Mar21-22:51:50/outputs/HW3-Train-3.teIn
# retrievalAlgorithm=Indri
# Indri:mu=1000
# Indri:lambda=0.7
# fb=true
# fbDocs=10
# fbTerms=10
# fbMu=0
# fbOrigWeight=0.5
# fbExpansionQueryFile=/bos/www/htdocs/classes/11-642/HW/HTS/uploads-hts-interim/HW3-xiaoyuh1-Mar21-22:51:50/outputs/HW3-Train-3.qryOut
# -- Your program stdout: --
# Memory used:
# 33 MB
# Query 26:lower heart rate
# -- Expand Query
# --> #and( #SCORE( lower.body ) #SCORE( heart.body ) #SCORE( rate.body ) )
# qexpanded:#wand (0.0014 your 0.0015 reebok 0.0015 kit 0.0019 london 0.0030 monitor 0.0064 hotel 0.0084 sensational 0.0084 heart 0.0131 lower 0.0178 rate )
# qcombined:#wand( 0.500000 #and(lower heart rate)
# 0.500000 #wand (0.0014 your 0.0015 reebok 0.0015 kit 0.0019 london 0.0030 monitor 0.0064 hotel 0.0084 sensational 0.0084 heart 0.0131 lower 0.0178 rate ) )
# --> #wand( #and( #SCORE( lower.body ) #SCORE( heart.body ) #SCORE( rate.body ) ) #wand( #SCORE( your.body ) #SCORE( reebok.body ) #SCORE( kit.body ) #SCORE( london.body ) #SCORE( monitor.body ) #SCORE( hotel.body ) #SCORE( sensational.body ) #SCORE( heart.body ) #SCORE( lower.body ) #SCORE( rate.body ) ) )
# write26 to file
# 26	Q0	clueweb09-en0003-91-09031	1	0.004000529658025326	run-1
# 26	Q0	clueweb09-en0003-91-08725	2	0.0038761674180208296	run-1
# 26	Q0	clueweb09-en0003-91-11074	3	0.002479483216917411	run-1
# 26	Q0	clueweb09-en0003-91-11151	4	0.002328894593208353	run-1
# 26	Q0	clueweb09-en0000-90-10551	5	0.0021007114849620695	run-1
# Time:
# 74076.352 ms
# -- trec_eval output: --
# num_q
# all	1
# num_ret
# all	100
# num_rel
# all	92
# num_rel_ret
# all	35
# map
# all	0.1311
# gm_ap
# all	0.1311
# R-prec
# all	0.3696
# bpref
# all	0.2688
# recip_rank
# all	0.1000
# ircl_prn.0.00
# all	0.4262
# ircl_prn.0.10
# all	0.4262
# ircl_prn.0.20
# all	0.4262
# ircl_prn.0.30
# all	0.4133
# ircl_prn.0.40
# all	0.0000
# ircl_prn.0.50
# all	0.0000
# ircl_prn.0.60
# all	0.0000
# ircl_prn.0.70
# all	0.0000
# ircl_prn.0.80
# all	0.0000
# ircl_prn.0.90
# all	0.0000
# ircl_prn.1.00
# all	0.0000
# P5
# all	0.0000
# P10
# all	0.1000
# P15
# all	0.2000
# P20
# all	0.2000
# P30
# all	0.3000
# P100
# all	0.3500
# P200
# all	0.1750
# P500
# all	0.0700
# P1000
# all	0.0350
# -- grade: --
# 100%
# ---- Test HW3-Train-4----
# Elapsed:
# 10 seconds
# Elapsed:
# 20 seconds
# Elapsed:
# 30 seconds
# Elapsed:
# 40 seconds
# -- Parameter file: --
# indexPath=/bos/www/htdocs/classes/11-642/HW/HTS/inputs/index
# queryFilePath=/bos/www/htdocs/classes/11-642/HW/HTS/tests/HW3-Train-4.qry
# trecEvalOutputPath=/bos/www/htdocs/classes/11-642/HW/HTS/uploads-hts-interim/HW3-xiaoyuh1-Mar21-22:51:50/outputs/HW3-Train-4.teIn
# retrievalAlgorithm=Indri
# Indri:mu=1000
# Indri:lambda=0.7
# fb=true
# fbDocs=10
# fbTerms=10
# fbMu=0
# fbOrigWeight=0.5
# fbExpansionQueryFile=/bos/www/htdocs/classes/11-642/HW/HTS/uploads-hts-interim/HW3-xiaoyuh1-Mar21-22:51:50/outputs/HW3-Train-4.qryOut
# -- Your program stdout: --
# Memory used:
# 31 MB
# Query 29:ps 2 games
# -- Expand Query
# --> #and( #SCORE( ps.body ) #SCORE( 2.body ) #SCORE( games.body ) )
# qexpanded:#wand (0.0067 com 0.0079 month 0.0088 pal 0.0096 torrent 0.0135 ps2dvd 0.0142 ago 0.0147 2 0.0202 ps2 0.0204 games 0.0249 ps )
# qcombined:#wand( 0.500000 #and(ps 2 games)
# 0.500000 #wand (0.0067 com 0.0079 month 0.0088 pal 0.0096 torrent 0.0135 ps2dvd 0.0142 ago 0.0147 2 0.0202 ps2 0.0204 games 0.0249 ps ) )
# --> #wand( #and( #SCORE( ps.body ) #SCORE( 2.body ) #SCORE( games.body ) ) #wand( #SCORE( com.body ) #SCORE( month.body ) #SCORE( pal.body ) #SCORE( torrent.body ) #SCORE( ps2dvd.body ) #SCORE( ago.body ) #SCORE( 2.body ) #SCORE( ps2.body ) #SCORE( games.body ) #SCORE( ps.body ) ) )
# write29 to file
# 29	Q0	clueweb09-en0011-98-19649	1	0.0074506611910534455	run-1
# 29	Q0	clueweb09-en0008-79-18869	2	0.00687977994367871	run-1
# 29	Q0	clueweb09-en0008-79-18868	3	0.006852486385388695	run-1
# 29	Q0	clueweb09-en0008-79-18871	4	0.005216125182524086	run-1
# 29	Q0	clueweb09-en0008-79-18870	5	0.0051172944566227	run-1
# Time:
# 39243.074 ms
# -- trec_eval output: --
# num_q
# all	1
# num_ret
# all	100
# num_rel
# all	14
# num_rel_ret
# all	5
# map
# all	0.0260
# gm_ap
# all	0.0260
# R-prec
# all	0.1429
# bpref
# all	0.0204
# recip_rank
# all	0.0769
# ircl_prn.0.00
# all	0.1429
# ircl_prn.0.10
# all	0.1429
# ircl_prn.0.20
# all	0.0538
# ircl_prn.0.30
# all	0.0538
# ircl_prn.0.40
# all	0.0000
# ircl_prn.0.50
# all	0.0000
# ircl_prn.0.60
# all	0.0000
# ircl_prn.0.70
# all	0.0000
# ircl_prn.0.80
# all	0.0000
# ircl_prn.0.90
# all	0.0000
# ircl_prn.1.00
# all	0.0000
# P5
# all	0.0000
# P10
# all	0.0000
# P15
# all	0.1333
# P20
# all	0.1000
# P30
# all	0.0667
# P100
# all	0.0500
# P200
# all	0.0250
# P500
# all	0.0100
# P1000
# all	0.0050
# -- grade: --
# 100%
# ---- Test HW3-Train-5----
# Elapsed:
# 10 seconds
# Elapsed:
# 20 seconds
# Elapsed:
# 30 seconds
# Elapsed:
# 40 seconds
# Elapsed:
# 50 seconds
# -- Parameter file: --
# indexPath=/bos/www/htdocs/classes/11-642/HW/HTS/inputs/index
# queryFilePath=/bos/www/htdocs/classes/11-642/HW/HTS/tests/HW3-Train-5.qry
# trecEvalOutputPath=/bos/www/htdocs/classes/11-642/HW/HTS/uploads-hts-interim/HW3-xiaoyuh1-Mar21-22:51:50/outputs/HW3-Train-5.teIn
# retrievalAlgorithm=Indri
# Indri:mu=1000
# Indri:lambda=0.7
# fb=true
# fbDocs=10
# fbTerms=10
# fbMu=0
# fbOrigWeight=0.5
# fbExpansionQueryFile=/bos/www/htdocs/classes/11-642/HW/HTS/uploads-hts-interim/HW3-xiaoyuh1-Mar21-22:51:50/outputs/HW3-Train-5.qryOut
# -- Your program stdout: --
# Memory used:
# 33 MB
# Query 33:elliptical trainer
# -- Expand Query
# --> #and( #SCORE( elliptic.body ) #SCORE( train.body ) )
# qexpanded:#wand (0.0104 crosstrainer 0.0125 horizon 0.0132 nordictrack 0.0149 exercise 0.0265 machine 0.0267 proform 0.0293 review 0.0316 fitness 0.1175 train 0.3202 elliptic )
# qcombined:#wand( 0.500000 #and(elliptical trainer)
# 0.500000 #wand (0.0104 crosstrainer 0.0125 horizon 0.0132 nordictrack 0.0149 exercise 0.0265 machine 0.0267 proform 0.0293 review 0.0316 fitness 0.1175 train 0.3202 elliptic ) )
# --> #wand( #and( #SCORE( elliptic.body ) #SCORE( train.body ) ) #wand( #SCORE( crosstrainer.body ) #SCORE( horizon.body ) #SCORE( nordictrack.body ) #SCORE( exercise.body ) #SCORE( machine.body ) #SCORE( proform.body ) #SCORE( review.body ) #SCORE( fitness.body ) #SCORE( train.body ) #SCORE( elliptic.body ) ) )
# write33 to file
# 33	Q0	clueweb09-en0004-10-03867	1	0.026795591486858977	run-1
# 33	Q0	clueweb09-en0003-85-29611	2	0.026464242326313395	run-1
# 33	Q0	clueweb09-en0001-84-08947	3	0.02619603373133852	run-1
# 33	Q0	clueweb09-en0008-88-09400	4	0.013703210697843821	run-1
# 33	Q0	clueweb09-en0007-93-27139	5	0.01142839318872414	run-1
# Time:
# 55035.365 ms
# -- trec_eval output: --
# num_q
# all	1
# num_ret
# all	100
# num_rel
# all	141
# num_rel_ret
# all	81
# map
# all	0.4303
# gm_ap
# all	0.4303
# R-prec
# all	0.5745
# bpref
# all	0.4990
# recip_rank
# all	0.2500
# ircl_prn.0.00
# all	0.8144
# ircl_prn.0.10
# all	0.8144
# ircl_prn.0.20
# all	0.8144
# ircl_prn.0.30
# all	0.8144
# ircl_prn.0.40
# all	0.8144
# ircl_prn.0.50
# all	0.8144
# ircl_prn.0.60
# all	0.0000
# ircl_prn.0.70
# all	0.0000
# ircl_prn.0.80
# all	0.0000
# ircl_prn.0.90
# all	0.0000
# ircl_prn.1.00
# all	0.0000
# P5
# all	0.4000
# P10
# all	0.7000
# P15
# all	0.7333
# P20
# all	0.7500
# P30
# all	0.7333
# P100
# all	0.8100
# P200
# all	0.4050
# P500
# all	0.1620
# P1000
# all	0.0810
# -- grade: --
# 100%
# ---- Test HW3-Train-6----
# Elapsed:
# 10 seconds
# Elapsed:
# 20 seconds
# Elapsed:
# 30 seconds
# Elapsed:
# 40 seconds
# -- Parameter file: --
# indexPath=/bos/www/htdocs/classes/11-642/HW/HTS/inputs/index
# queryFilePath=/bos/www/htdocs/classes/11-642/HW/HTS/tests/HW3-Train-6.qry
# trecEvalOutputPath=/bos/www/htdocs/classes/11-642/HW/HTS/uploads-hts-interim/HW3-xiaoyuh1-Mar21-22:51:50/outputs/HW3-Train-6.teIn
# retrievalAlgorithm=Indri
# Indri:mu=1000
# Indri:lambda=0.7
# fb=true
# fbDocs=10
# fbTerms=10
# fbMu=0
# fbOrigWeight=0.5
# fbExpansionQueryFile=/bos/www/htdocs/classes/11-642/HW/HTS/uploads-hts-interim/HW3-xiaoyuh1-Mar21-22:51:50/outputs/HW3-Train-6.qryOut
# -- Your program stdout: --
# Memory used:
# 33 MB
# Query 52:avp
# -- Expand Query
# --> #SCORE( avp.body )
# qexpanded:#wand (0.0070 vs 0.0088 volleyball 0.0090 alien 0.0092 season 0.0092 beach 0.0101 event 0.0142 tour 0.0189 antiviru 0.0313 newsletter 0.1777 avp )
# qcombined:#wand( 0.500000 #and(avp)
# 0.500000 #wand (0.0070 vs 0.0088 volleyball 0.0090 alien 0.0092 season 0.0092 beach 0.0101 event 0.0142 tour 0.0189 antiviru 0.0313 newsletter 0.1777 avp ) )
# --> #wand( #SCORE( avp.body ) #wand( #SCORE( vs.body ) #SCORE( volleyball.body ) #SCORE( alien.body ) #SCORE( season.body ) #SCORE( beach.body ) #SCORE( event.body ) #SCORE( tour.body ) #SCORE( antiviru.body ) #SCORE( newsletter.body ) #SCORE( avp.body ) ) )
# write52 to file
# 52	Q0	clueweb09-en0002-02-06958	1	0.008421428510730683	run-1
# 52	Q0	clueweb09-en0004-50-29420	2	0.008097212274118224	run-1
# 52	Q0	clueweb09-en0007-37-33556	3	0.0053130765144994326	run-1
# 52	Q0	clueweb09-en0009-11-15253	4	0.005299393552805481	run-1
# 52	Q0	clueweb09-en0003-86-25212	5	0.0052922144035117665	run-1
# Time:
# 45829.178 ms
# -- trec_eval output: --
# num_q
# all	1
# num_ret
# all	100
# num_rel
# all	47
# num_rel_ret
# all	23
# map
# all	0.1740
# gm_ap
# all	0.1740
# R-prec
# all	0.3191
# bpref
# all	0.2322
# recip_rank
# all	0.2500
# ircl_prn.0.00
# all	0.5556
# ircl_prn.0.10
# all	0.5556
# ircl_prn.0.20
# all	0.3939
# ircl_prn.0.30
# all	0.3191
# ircl_prn.0.40
# all	0.2676
# ircl_prn.0.50
# all	0.0000
# ircl_prn.0.60
# all	0.0000
# ircl_prn.0.70
# all	0.0000
# ircl_prn.0.80
# all	0.0000
# ircl_prn.0.90
# all	0.0000
# ircl_prn.1.00
# all	0.0000
# P5
# all	0.4000
# P10
# all	0.5000
# P15
# all	0.4667
# P20
# all	0.4000
# P30
# all	0.3667
# P100
# all	0.2300
# P200
# all	0.1150
# P500
# all	0.0460
# P1000
# all	0.0230
# -- grade: --
# 100%
# ---- Test HW3-Train-7----
# Elapsed:
# 10 seconds
# Elapsed:
# 20 seconds
# Elapsed:
# 30 seconds
# Elapsed:
# 40 seconds
# Elapsed:
# 50 seconds
# Elapsed:
# 60 seconds
# -- Parameter file: --
# indexPath=/bos/www/htdocs/classes/11-642/HW/HTS/inputs/index
# queryFilePath=/bos/www/htdocs/classes/11-642/HW/HTS/tests/HW3-Train-7.qry
# trecEvalOutputPath=/bos/www/htdocs/classes/11-642/HW/HTS/uploads-hts-interim/HW3-xiaoyuh1-Mar21-22:51:50/outputs/HW3-Train-7.teIn
# retrievalAlgorithm=Indri
# Indri:mu=1000
# Indri:lambda=0.7
# fb=true
# fbDocs=10
# fbTerms=10
# fbMu=0
# fbOrigWeight=0.5
# fbExpansionQueryFile=/bos/www/htdocs/classes/11-642/HW/HTS/uploads-hts-interim/HW3-xiaoyuh1-Mar21-22:51:50/outputs/HW3-Train-7.qryOut
# -- Your program stdout: --
# Memory used:
# 33 MB
# Query 71:living in india
# -- Expand Query
# --> #and( #SCORE( living.body ) #SCORE( india.body ) )
# qexpanded:#wand (0.0035 room 0.0036 independent 0.0037 casuarina 0.0038 expat 0.0054 wooden 0.0060 island 0.0080 living 0.0085 hick 0.0088 furniture 0.0436 india )
# qcombined:#wand( 0.500000 #and(living in india)
# 0.500000 #wand (0.0035 room 0.0036 independent 0.0037 casuarina 0.0038 expat 0.0054 wooden 0.0060 island 0.0080 living 0.0085 hick 0.0088 furniture 0.0436 india ) )
# --> #wand( #and( #SCORE( living.body ) #SCORE( india.body ) ) #wand( #SCORE( room.body ) #SCORE( independent.body ) #SCORE( casuarina.body ) #SCORE( expat.body ) #SCORE( wooden.body ) #SCORE( island.body ) #SCORE( living.body ) #SCORE( hick.body ) #SCORE( furniture.body ) #SCORE( india.body ) ) )
# write71 to file
# 71	Q0	clueweb09-en0003-69-28041	1	0.003797699110474702	run-1
# 71	Q0	clueweb09-en0001-86-16575	2	0.0031586164067869075	run-1
# 71	Q0	clueweb09-en0004-37-01664	3	0.002912595225644976	run-1
# 71	Q0	clueweb09-en0006-65-34164	4	0.002517766804649231	run-1
# 71	Q0	clueweb09-en0003-72-10841	5	0.002444524789836874	run-1
# Time:
# 57372.185 ms
# -- trec_eval output: --
# num_q
# all	1
# num_ret
# all	100
# num_rel
# all	91
# num_rel_ret
# all	17
# map
# all	0.0216
# gm_ap
# all	0.0216
# R-prec
# all	0.0989
# bpref
# all	0.1257
# recip_rank
# all	0.0667
# ircl_prn.0.00
# all	0.1700
# ircl_prn.0.10
# all	0.1700
# ircl_prn.0.20
# all	0.0000
# ircl_prn.0.30
# all	0.0000
# ircl_prn.0.40
# all	0.0000
# ircl_prn.0.50
# all	0.0000
# ircl_prn.0.60
# all	0.0000
# ircl_prn.0.70
# all	0.0000
# ircl_prn.0.80
# all	0.0000
# ircl_prn.0.90
# all	0.0000
# ircl_prn.1.00
# all	0.0000
# P5
# all	0.0000
# P10
# all	0.0000
# P15
# all	0.0667
# P20
# all	0.0500
# P30
# all	0.0333
# P100
# all	0.1700
# P200
# all	0.0850
# P500
# all	0.0340
# P1000
# all	0.0170
# -- grade: --
# 100%
# ---- Test HW3-Train-8----
# Elapsed:
# 10 seconds
# Elapsed:
# 20 seconds
# Elapsed:
# 30 seconds
# -- Parameter file: --
# indexPath=/bos/www/htdocs/classes/11-642/HW/HTS/inputs/index
# queryFilePath=/bos/www/htdocs/classes/11-642/HW/HTS/tests/HW3-Train-8.qry
# trecEvalOutputPath=/bos/www/htdocs/classes/11-642/HW/HTS/uploads-hts-interim/HW3-xiaoyuh1-Mar21-22:51:50/outputs/HW3-Train-8.teIn
# retrievalAlgorithm=Indri
# Indri:mu=1000
# Indri:lambda=0.7
# fb=true
# fbDocs=10
# fbTerms=10
# fbMu=0
# fbOrigWeight=0.5
# fbExpansionQueryFile=/bos/www/htdocs/classes/11-642/HW/HTS/uploads-hts-interim/HW3-xiaoyuh1-Mar21-22:51:50/outputs/HW3-Train-8.qryOut
# -- Your program stdout: --
# Memory used:
# 33 MB
# Query 102:fickle creek farm
# -- Expand Query
# --> #and( #SCORE( fickle.body ) #SCORE( creek.body ) #SCORE( farm.body ) )
# qexpanded:#wand (0.0003 clear 0.0003 fence 0.0003 news 0.0003 web 0.0004 worm 0.0005 arabia 0.0011 twin 0.0012 bait 0.0016 creek 0.0024 farm )
# qcombined:#wand( 0.500000 #and(fickle creek farm)
# 0.500000 #wand (0.0003 clear 0.0003 fence 0.0003 news 0.0003 web 0.0004 worm 0.0005 arabia 0.0011 twin 0.0012 bait 0.0016 creek 0.0024 farm ) )
# --> #wand( #and( #SCORE( fickle.body ) #SCORE( creek.body ) #SCORE( farm.body ) ) #wand( #SCORE( clear.body ) #SCORE( fence.body ) #SCORE( news.body ) #SCORE( web.body ) #SCORE( worm.body ) #SCORE( arabia.body ) #SCORE( twin.body ) #SCORE( bait.body ) #SCORE( creek.body ) #SCORE( farm.body ) ) )
# write102 to file
# 102	Q0	clueweb09-en0000-31-10629	1	0.0013205616926186808	run-1
# 102	Q0	clueweb09-en0004-54-25496	2	0.0013185690815148375	run-1
# 102	Q0	clueweb09-en0007-98-05165	3	7.796679962399834E-4	run-1
# 102	Q0	clueweb09-en0009-21-19078	4	6.394248675240726E-4	run-1
# 102	Q0	clueweb09-en0009-30-26210	5	6.382647594928468E-4	run-1
# Time:
# 35032.603 ms
# -- trec_eval output: --
# num_q
# all	1
# num_ret
# all	100
# num_rel
# all	22
# num_rel_ret
# all	1
# map
# all	0.0012
# gm_ap
# all	0.0012
# R-prec
# all	0.0000
# bpref
# all	0.0000
# recip_rank
# all	0.0263
# ircl_prn.0.00
# all	0.0263
# ircl_prn.0.10
# all	0.0000
# ircl_prn.0.20
# all	0.0000
# ircl_prn.0.30
# all	0.0000
# ircl_prn.0.40
# all	0.0000
# ircl_prn.0.50
# all	0.0000
# ircl_prn.0.60
# all	0.0000
# ircl_prn.0.70
# all	0.0000
# ircl_prn.0.80
# all	0.0000
# ircl_prn.0.90
# all	0.0000
# ircl_prn.1.00
# all	0.0000
# P5
# all	0.0000
# P10
# all	0.0000
# P15
# all	0.0000
# P20
# all	0.0000
# P30
# all	0.0000
# P100
# all	0.0100
# P200
# all	0.0050
# P500
# all	0.0020
# P1000
# all	0.0010
# -- grade: --
# 100%
# ---- Test HW3-Train-9----
# Elapsed:
# 10 seconds
# Elapsed:
# 20 seconds
# Elapsed:
# 30 seconds
# -- Parameter file: --
# indexPath=/bos/www/htdocs/classes/11-642/HW/HTS/inputs/index
# queryFilePath=/bos/www/htdocs/classes/11-642/HW/HTS/tests/HW3-Train-9.qry
# trecEvalOutputPath=/bos/www/htdocs/classes/11-642/HW/HTS/uploads-hts-interim/HW3-xiaoyuh1-Mar21-22:51:50/outputs/HW3-Train-9.teIn
# retrievalAlgorithm=Indri
# Indri:mu=1000
# Indri:lambda=0.7
# fb=true
# fbDocs=10
# fbTerms=10
# fbMu=0
# fbOrigWeight=0.5
# fbExpansionQueryFile=/bos/www/htdocs/classes/11-642/HW/HTS/uploads-hts-interim/HW3-xiaoyuh1-Mar21-22:51:50/outputs/HW3-Train-9.qryOut
# -- Your program stdout: --
# Memory used:
# 33 MB
# Query 149:uplift at yellowstone national park
# -- Expand Query
# --> #and( #SCORE( uplift.body ) #SCORE( yellowstone.body ) #SCORE( national.body ) #SCORE( park.body ) )
# qexpanded:#wand (0.0016 swarm 0.0017 observatory 0.0018 coyote 0.0020 nyellowstone 0.0025 yvo 0.0032 earthquake 0.0033 volcano 0.0065 national 0.0080 park 0.0245 yellowstone )
# qcombined:#wand( 0.500000 #and(uplift at yellowstone national park)
# 0.500000 #wand (0.0016 swarm 0.0017 observatory 0.0018 coyote 0.0020 nyellowstone 0.0025 yvo 0.0032 earthquake 0.0033 volcano 0.0065 national 0.0080 park 0.0245 yellowstone ) )
# --> #wand( #and( #SCORE( uplift.body ) #SCORE( yellowstone.body ) #SCORE( national.body ) #SCORE( park.body ) ) #wand( #SCORE( swarm.body ) #SCORE( observatory.body ) #SCORE( coyote.body ) #SCORE( nyellowstone.body ) #SCORE( yvo.body ) #SCORE( earthquake.body ) #SCORE( volcano.body ) #SCORE( national.body ) #SCORE( park.body ) #SCORE( yellowstone.body ) ) )
# write149 to file
# 149	Q0	clueweb09-en0004-04-24081	1	0.0035542804480593513	run-1
# 149	Q0	clueweb09-en0000-54-05204	2	0.0034866410002990914	run-1
# 149	Q0	clueweb09-en0003-01-26777	3	0.003200787061969892	run-1
# 149	Q0	clueweb09-en0004-31-10704	4	0.003137216787286535	run-1
# 149	Q0	clueweb09-en0003-01-26776	5	0.0031192821196568453	run-1
# Time:
# 37427.053 ms
# -- trec_eval output: --
# num_q
# all	1
# num_ret
# all	100
# num_rel
# all	62
# num_rel_ret
# all	33
# map
# all	0.1781
# gm_ap
# all	0.1781
# R-prec
# all	0.3226
# bpref
# all	0.2711
# recip_rank
# all	0.0909
# ircl_prn.0.00
# all	0.5000
# ircl_prn.0.10
# all	0.5000
# ircl_prn.0.20
# all	0.3611
# ircl_prn.0.30
# all	0.3500
# ircl_prn.0.40
# all	0.3500
# ircl_prn.0.50
# all	0.3300
# ircl_prn.0.60
# all	0.0000
# ircl_prn.0.70
# all	0.0000
# ircl_prn.0.80
# all	0.0000
# ircl_prn.0.90
# all	0.0000
# ircl_prn.1.00
# all	0.0000
# P5
# all	0.0000
# P10
# all	0.0000
# P15
# all	0.2667
# P20
# all	0.4500
# P30
# all	0.4000
# P100
# all	0.3300
# P200
# all	0.1650
# P500
# all	0.0660
# P1000
# all	0.0330
# -- grade: --
# 100%
# ---- End of your system's output ----
# ---- Done ----

# %%
# checklist = getCheckListPlayload(range(10, 20))
# autoCheckCorrectness(checklist)
checklist = getCheckListPlayload([20, 21, 22])
autoCheckCorrectness(checklist)
